# %%
import pandas as pd
import numpy as np
import glob
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
from openpyxl import Workbook
#from scipy.interpolate import interpld
from scipy.interpolate import spline
import math

# %%
fout = 'BO1_C05_'
filepath1 = 'H:/HEA/Finished/C05_BO1_2345674'
#filepath2 = 'H:/HEA/Finished/C01_BO1_2345675'
#filepath3 = 'H:/HEA/Finished/C01_BO1_2345676'
#filepath4 = 'H:/HEA/Finished/C01_BO1_2345677'
#filepath5 = 'H:/HEA/Finished/C01_BO1_2345678'
# filepath1 = 'C:/Users/Tim.Jason-PC/Desktop/HEY/研究交接資料/fraction_of_Mn/Co23Ni23Cr23Fe23Mn8_110_modify/1_1500K/'
# filepath2 = 'C:/Users/Tim.Jason-PC/Desktop/HEY/研究交接資料/Fe/Fe0/20150901_100800/2_tension_1e-3_300K_sss_fracture_4/'
# filepath3 = 'C:/Users/Tim.Jason-PC/Desktop/HEY/研究交接資料/fraction_of_Mn/co25ni25cr25fe25_110_modify/20150901_100800/2_tension_1e-3_300K_sss_fracture_4/'
# filepath4 = 'C:/Users/Tim.Jason-PC/Desktop/HEY/研究交接資料/fraction_of_Mn/Co23Ni23Cr23Fe23Mn8_110_modify/1_1500K/'
# filepath5 = 'C:/Users/Tim.Jason-PC/Desktop/HEY/研究交接資料/Fe/Fe0/20150901_100800/2_tension_1e-3_300K_sss_fracture_4/'
#filepath = 'D:/tensile_md/test/real_final3/normal/'

all_files1 = glob.glob(filepath1 + '/dump/eq20_uniaxial.mid_convert.*')
#all_files2 = glob.glob(filepath2 + '/dump/eq20_uniaxial.mid_convert.*')
#all_files3 = glob.glob(filepath3 + '/dump/eq20_uniaxial.mid_convert.*')
#all_files4 = glob.glob(filepath4 + '/dump/eq20_uniaxial.mid_convert.*')
#all_files5 = glob.glob(filepath5 + '/dump/eq20_uniaxial.mid_convert.*')

files_number1 = [[file, (int)(file.split('.')[-1])] for file in all_files1]
#files_number2 = [[file, (int)(file.split('.')[-1])] for file in all_files2]
#files_number3 = [[file, (int)(file.split('.')[-1])] for file in all_files3]
#files_number4 = [[file, (int)(file.split('.')[-1])] for file in all_files4]
#files_number5 = [[file, (int)(file.split('.')[-1])] for file in all_files5]

sort_files1 = sorted(files_number1, key=lambda x: x[1])
#sort_files2 = sorted(files_number2, key=lambda x: x[1])
#sort_files3 = sorted(files_number3, key=lambda x: x[1])
#sort_files4 = sorted(files_number4, key=lambda x: x[1])
#sort_files5 = sorted(files_number5, key=lambda x: x[1])

final_files1 = [x[0] for x in sort_files1]
#final_files2 = [x[0] for x in sort_files2]
#final_files3 = [x[0] for x in sort_files3]
#final_files4 = [x[0] for x in sort_files4]
#final_files5 = [x[0] for x in sort_files5]
print(final_files1)
#print(final_files2)
#print(final_files3)
#print(final_files4)
#print(final_files5)


#print(all_files[1])
#print(files_number[1])
#print(sort_files[1])
#print(final_files1)
#print(final_files2)
#print(final_files3)
# Out:
# ['H:/HEA/Finished/C05_BO1_2345674/dump\\eq20_uniaxial.mid_convert.0', 'H:/HEA/Finished/C05_BO1_2345674/dump\\eq20_uniaxial.mid_convert.1000', 'H:/HEA/Finished/C05_BO1_2345674/dump\\eq20_uniaxial.mid_convert.2000', 'H:/HEA/Finished/C05_BO1_2345674/dump\\eq20_uniaxial.mid_convert.3000', 'H:/HEA/Finished/C05_BO1_2345674/dump\\eq20_uniaxial.mid_convert.4000', 'H:/HEA/Finished/C05_BO1_2345674/dump\\eq20_uniaxial.mid_convert.5000', 'H:/HEA/Finished/C05_BO1_2345674/dump\\eq20_uniaxial.mid_convert.6000', 'H:/HEA/Finished/C05_BO1_2345674/dump\\eq20_uniaxial.mid_convert.7000', 'H:/HEA/Finished/C05_BO1_2345674/dump\\eq20_uniaxial.mid_convert.8000', 'H:/HEA/Finished/C05_BO1_2345674/dump\\eq20_uniaxial.mid_convert.9000', 'H:/HEA/Finished/C05_BO1_2345674/dump\\eq20_uniaxial.mid_convert.10000', 'H:/HEA/Finished/C05_BO1_2345674/dump\\eq20_uniaxial.mid_convert.11000', 'H:/HEA/Finished/C05_BO1_2345674/dump\\eq20_uniaxial.mid_convert.12000', 'H:/HEA/Finished/C05_BO1_2345674/dump\\eq20_uniaxial.mid_convert.13000', 'H:/HEA/Finished/C05_BO1_2345674/dump\\eq20_uniaxial.mid_convert.14000', 'H:/HEA/Finished/C05_BO1_2345674/dump\\eq20_uniaxial.mid_convert.15000', 'H:/HEA/Finished/C05_BO1_2345674/dump\\eq20_uniaxial.mid_convert.16000', 'H:/HEA/Finished/C05_BO1_2345674/dump\\eq20_uniaxial.mid_convert.17000', 'H:/HEA/Finished/C05_BO1_2345674/dump\\eq20_uniaxial.mid_convert.18000', 'H:/HEA/Finished/C05_BO1_2345674/dump\\eq20_uniaxial.mid_convert.19000', 'H:/HEA/Finished/C05_BO1_2345674/dump\\eq20_uniaxial.mid_convert.20000', 'H:/HEA/Finished/C05_BO1_2345674/dump\\eq20_uniaxial.mid_convert.21000', 'H:/HEA/Finished/C05_BO1_2345674/dump\\eq20_uniaxial.mid_convert.22000', 'H:/HEA/Finished/C05_BO1_2345674/dump\\eq20_uniaxial.mid_convert.23000', 'H:/HEA/Finished/C05_BO1_2345674/dump\\eq20_uniaxial.mid_convert.24000', 'H:/HEA/Finished/C05_BO1_2345674/dump\\eq20_uniaxial.mid_convert.25000', 'H:/HEA/Finished/C05_BO1_2345674/dump\\eq20_uniaxial.mid_convert.26000', 'H:/HEA/Finished/C05_BO1_2345674/dump\\eq20_uniaxial.mid_convert.27000', 'H:/HEA/Finished/C05_BO1_2345674/dump\\eq20_uniaxial.mid_convert.28000', 'H:/HEA/Finished/C05_BO1_2345674/dump\\eq20_uniaxial.mid_convert.29000', 'H:/HEA/Finished/C05_BO1_2345674/dump\\eq20_uniaxial.mid_convert.30000', 'H:/HEA/Finished/C05_BO1_2345674/dump\\eq20_uniaxial.mid_convert.31000', 'H:/HEA/Finished/C05_BO1_2345674/dump\\eq20_uniaxial.mid_convert.32000', 'H:/HEA/Finished/C05_BO1_2345674/dump\\eq20_uniaxial.mid_convert.33000', 'H:/HEA/Finished/C05_BO1_2345674/dump\\eq20_uniaxial.mid_convert.34000', 'H:/HEA/Finished/C05_BO1_2345674/dump\\eq20_uniaxial.mid_convert.35000', 'H:/HEA/Finished/C05_BO1_2345674/dump\\eq20_uniaxial.mid_convert.36000', 'H:/HEA/Finished/C05_BO1_2345674/dump\\eq20_uniaxial.mid_convert.37000', 'H:/HEA/Finished/C05_BO1_2345674/dump\\eq20_uniaxial.mid_convert.38000', 'H:/HEA/Finished/C05_BO1_2345674/dump\\eq20_uniaxial.mid_convert.39000', 'H:/HEA/Finished/C05_BO1_2345674/dump\\eq20_uniaxial.mid_convert.40000', 'H:/HEA/Finished/C05_BO1_2345674/dump\\eq20_uniaxial.mid_convert.41000', 'H:/HEA/Finished/C05_BO1_2345674/dump\\eq20_uniaxial.mid_convert.42000', 'H:/HEA/Finished/C05_BO1_2345674/dump\\eq20_uniaxial.mid_convert.43000', 'H:/HEA/Finished/C05_BO1_2345674/dump\\eq20_uniaxial.mid_convert.44000', 'H:/HEA/Finished/C05_BO1_2345674/dump\\eq20_uniaxial.mid_convert.45000', 'H:/HEA/Finished/C05_BO1_2345674/dump\\eq20_uniaxial.mid_convert.46000', 'H:/HEA/Finished/C05_BO1_2345674/dump\\eq20_uniaxial.mid_convert.47000', 'H:/HEA/Finished/C05_BO1_2345674/dump\\eq20_uniaxial.mid_convert.48000', 'H:/HEA/Finished/C05_BO1_2345674/dump\\eq20_uniaxial.mid_convert.49000', 'H:/HEA/Finished/C05_BO1_2345674/dump\\eq20_uniaxial.mid_convert.50000', 'H:/HEA/Finished/C05_BO1_2345674/dump\\eq20_uniaxial.mid_convert.51000', 'H:/HEA/Finished/C05_BO1_2345674/dump\\eq20_uniaxial.mid_convert.52000', 'H:/HEA/Finished/C05_BO1_2345674/dump\\eq20_uniaxial.mid_convert.53000', 'H:/HEA/Finished/C05_BO1_2345674/dump\\eq20_uniaxial.mid_convert.54000 ...

# %%
#loadedFiles = [final_files1, final_files2, final_files3, final_files4, final_files5]
loadedFiles = [final_files1]
print(loadedFiles)
# Out:
# [['H:/HEA/Finished/C05_BO1_2345674/dump\\eq20_uniaxial.mid_convert.0', 'H:/HEA/Finished/C05_BO1_2345674/dump\\eq20_uniaxial.mid_convert.1000', 'H:/HEA/Finished/C05_BO1_2345674/dump\\eq20_uniaxial.mid_convert.2000', 'H:/HEA/Finished/C05_BO1_2345674/dump\\eq20_uniaxial.mid_convert.3000', 'H:/HEA/Finished/C05_BO1_2345674/dump\\eq20_uniaxial.mid_convert.4000', 'H:/HEA/Finished/C05_BO1_2345674/dump\\eq20_uniaxial.mid_convert.5000', 'H:/HEA/Finished/C05_BO1_2345674/dump\\eq20_uniaxial.mid_convert.6000', 'H:/HEA/Finished/C05_BO1_2345674/dump\\eq20_uniaxial.mid_convert.7000', 'H:/HEA/Finished/C05_BO1_2345674/dump\\eq20_uniaxial.mid_convert.8000', 'H:/HEA/Finished/C05_BO1_2345674/dump\\eq20_uniaxial.mid_convert.9000', 'H:/HEA/Finished/C05_BO1_2345674/dump\\eq20_uniaxial.mid_convert.10000', 'H:/HEA/Finished/C05_BO1_2345674/dump\\eq20_uniaxial.mid_convert.11000', 'H:/HEA/Finished/C05_BO1_2345674/dump\\eq20_uniaxial.mid_convert.12000', 'H:/HEA/Finished/C05_BO1_2345674/dump\\eq20_uniaxial.mid_convert.13000', 'H:/HEA/Finished/C05_BO1_2345674/dump\\eq20_uniaxial.mid_convert.14000', 'H:/HEA/Finished/C05_BO1_2345674/dump\\eq20_uniaxial.mid_convert.15000', 'H:/HEA/Finished/C05_BO1_2345674/dump\\eq20_uniaxial.mid_convert.16000', 'H:/HEA/Finished/C05_BO1_2345674/dump\\eq20_uniaxial.mid_convert.17000', 'H:/HEA/Finished/C05_BO1_2345674/dump\\eq20_uniaxial.mid_convert.18000', 'H:/HEA/Finished/C05_BO1_2345674/dump\\eq20_uniaxial.mid_convert.19000', 'H:/HEA/Finished/C05_BO1_2345674/dump\\eq20_uniaxial.mid_convert.20000', 'H:/HEA/Finished/C05_BO1_2345674/dump\\eq20_uniaxial.mid_convert.21000', 'H:/HEA/Finished/C05_BO1_2345674/dump\\eq20_uniaxial.mid_convert.22000', 'H:/HEA/Finished/C05_BO1_2345674/dump\\eq20_uniaxial.mid_convert.23000', 'H:/HEA/Finished/C05_BO1_2345674/dump\\eq20_uniaxial.mid_convert.24000', 'H:/HEA/Finished/C05_BO1_2345674/dump\\eq20_uniaxial.mid_convert.25000', 'H:/HEA/Finished/C05_BO1_2345674/dump\\eq20_uniaxial.mid_convert.26000', 'H:/HEA/Finished/C05_BO1_2345674/dump\\eq20_uniaxial.mid_convert.27000', 'H:/HEA/Finished/C05_BO1_2345674/dump\\eq20_uniaxial.mid_convert.28000', 'H:/HEA/Finished/C05_BO1_2345674/dump\\eq20_uniaxial.mid_convert.29000', 'H:/HEA/Finished/C05_BO1_2345674/dump\\eq20_uniaxial.mid_convert.30000', 'H:/HEA/Finished/C05_BO1_2345674/dump\\eq20_uniaxial.mid_convert.31000', 'H:/HEA/Finished/C05_BO1_2345674/dump\\eq20_uniaxial.mid_convert.32000', 'H:/HEA/Finished/C05_BO1_2345674/dump\\eq20_uniaxial.mid_convert.33000', 'H:/HEA/Finished/C05_BO1_2345674/dump\\eq20_uniaxial.mid_convert.34000', 'H:/HEA/Finished/C05_BO1_2345674/dump\\eq20_uniaxial.mid_convert.35000', 'H:/HEA/Finished/C05_BO1_2345674/dump\\eq20_uniaxial.mid_convert.36000', 'H:/HEA/Finished/C05_BO1_2345674/dump\\eq20_uniaxial.mid_convert.37000', 'H:/HEA/Finished/C05_BO1_2345674/dump\\eq20_uniaxial.mid_convert.38000', 'H:/HEA/Finished/C05_BO1_2345674/dump\\eq20_uniaxial.mid_convert.39000', 'H:/HEA/Finished/C05_BO1_2345674/dump\\eq20_uniaxial.mid_convert.40000', 'H:/HEA/Finished/C05_BO1_2345674/dump\\eq20_uniaxial.mid_convert.41000', 'H:/HEA/Finished/C05_BO1_2345674/dump\\eq20_uniaxial.mid_convert.42000', 'H:/HEA/Finished/C05_BO1_2345674/dump\\eq20_uniaxial.mid_convert.43000', 'H:/HEA/Finished/C05_BO1_2345674/dump\\eq20_uniaxial.mid_convert.44000', 'H:/HEA/Finished/C05_BO1_2345674/dump\\eq20_uniaxial.mid_convert.45000', 'H:/HEA/Finished/C05_BO1_2345674/dump\\eq20_uniaxial.mid_convert.46000', 'H:/HEA/Finished/C05_BO1_2345674/dump\\eq20_uniaxial.mid_convert.47000', 'H:/HEA/Finished/C05_BO1_2345674/dump\\eq20_uniaxial.mid_convert.48000', 'H:/HEA/Finished/C05_BO1_2345674/dump\\eq20_uniaxial.mid_convert.49000', 'H:/HEA/Finished/C05_BO1_2345674/dump\\eq20_uniaxial.mid_convert.50000', 'H:/HEA/Finished/C05_BO1_2345674/dump\\eq20_uniaxial.mid_convert.51000', 'H:/HEA/Finished/C05_BO1_2345674/dump\\eq20_uniaxial.mid_convert.52000', 'H:/HEA/Finished/C05_BO1_2345674/dump\\eq20_uniaxial.mid_convert.53000', 'H:/HEA/Finished/C05_BO1_2345674/dump\\eq20_uniaxial.mid_convert.5400 ...

# %%
allStress_eq20 = []

count = 1
run = 1

for finalFiles in loadedFiles:
    listName = 'v_s15__' + str(run)
    listName = []
    
    for file in finalFiles:
        df = pd.read_csv(file, skiprows=8, sep=" ", engine='python')
        df = df.dropna(axis=1)
        try:
            df.columns = ['ATOMS id', 'type', 'x', 'y', 'z', 'v_s4', 'v_s5', 'v_s6','v_s14', 'v_s15', 'v_s16']
        except:
            print('Error.')
            print("There is nan in " + str(file))
            break
        s_df = df.astype(str)
        if sum(df['v_s15'])<-0.001 and count > 10:
            print("Negative stress, end of calculation " + str(run) + " !")
            break
        #elif s_df11["v_s15"].str.contains("nan").any() or s_df11["v_s15"].str.contains("-nan").any():
        elif any("nan" in s15 for s15 in s_df['v_s15']):
            print("Nan exists in file " + str(file))
            break
        else:
            ans = sum(df['v_s15'])
            print(ans)
            listName.append(ans)
        count += 1
    allStress_eq20.append(listName)
    print("Run " + str(run) + " finished!!!!!!!!!!!!!!!!!!!")
    count = 1
    run += 1
# Out:
# -0.0016460251347710378
# 0.030252549419051398
# 0.0384407042976989
# 0.0696371244960472
# 0.09420209276563273
# 0.11561828015342528
# 0.15356792274412168
# 0.17699767613777798
# 0.21620397388074836
# 0.2417865072788754
# 0.2694100827124438
# 0.3007130053763431
# 0.3264612412462085
# 0.3495862952497694
# 0.36777727443354746
# 0.37073747573594534
# 0.35682859724075067
# 0.3320830556827604
# 0.31816393071579413
# 0.3120476496815642
# 0.2994735611130281
# 0.28856037878570473
# 0.2700914197451048
# 0.2543398010634192
# 0.23871259169946388
# 0.2309485477389396
# 0.22546678343606946
# 0.2135025551684375
# 0.21099323749186524
# 0.213788533467088
# 0.211668228043991
# 0.21858356440587362
# 0.2176385287625226
# 0.22556973606460407
# 0.2220741281518681
# 0.22375164929605673
# 0.2228700248172977
# 0.2238989657984048
# 0.22388621386802934
# 0.22339255797374513
# 0.21979700820421022
# 0.22120668244226732
# 0.21831120902171178
# 0.22128676449889173
# 0.22023988874015085
# 0.22068250627790076
# 0.21312830604436606
# 0.20574718349779147
# 0.19980085644561194
# 0.1941791677684744
# 0.19310366048823938
# 0.1880964375111156
# 0.18181579763122793
# 0.17804926116602438
# 0.17397757650607426
# 0.17235610452689196
# 0.16988175707642883
# 0.16838229971166996
# 0.1694141422624262
# 0.16381747136047053
# 0.16160903323333903
# 0.1612001907333235
# 0.16049774727716595
# 0.15816947611199483
# 0.15896582919019142
# 0.15916667905020376
# 0.16165868779557052
# 0.16295510605513464
# 0.1580147663412239
# 0.1534034804780436
# 0.14974410420001819
# 0.14766350681268647
# 0.14256982901999748
# 0.1396531914375813
# 0.13608935527953842
# 0.1335992115527615
# 0.13833751066637442
# 0.13324697850285586
# 0.13110887007114314
# 0.13368866825352674
# 0.12810035899755925
# 0.13237704570336084
# 0.12690067605533092
# 0.12582691936720225
# 0.12365082153053256
# 0.1208223430555036
# 0.11770328889867397
# 0.11027293473929106
# 0.10860695312409213
# 0.10316168446102009
# 0.09961676558610828
# 0.10037430034073501
# 0.09744678410599465
# 0.09400374951069723
# 0.09363944045975967
# 0.09396015023817599
# 0.09143022266891114
# 0.09354910842867614
# 0.09059161226063828
# 0.09028262759019162
# 0.09069708855661342
# 0.08753769756260811
# 0.09267787436089324
# 0.08515790303730154
# 0.08524326114248335
# 0.07859214642275678
# 0.07783695597887941
# 0.07519281423519808
# 0.07166077827161371
# 0.06969540400957043
# 0.06985715069141907
# 0.06638027143608988
# 0.0679360288492266
# 0.06926019983880911
# 0.0679533144971404
# 0.06587071849311989
# 0.06255452242723643
# 0.06442318331261382
# 0.06175701688578697
# 0.06116808597121986
# 0.06057556723528718
# 0.0566231609041539
# 0.053265076907322996
# 0.054307681380445276
# 0.0501717323645981
# 0.049580021896294985
# 0.04733549283343707
# 0.04487781245633688
# 0.0478242365842617
# 0.044109889501838674
# 0.04377587868167436
# 0.04531947934899073
# 0.04207745491326326
# 0.039084388957162854
# 0.04048281045130318
# 0.04175125522300861
# 0.042689703099176926
# 0.041184229786749654
# 0.04018859059843656
# 0.040437450034407976
# 0.04108418056364734
# 0.03833311564060258
# 0.03590414146017647
# 0.035934205719782245
# 0.03269157527158968
# 0.02737097494212045
# 0.0261158059748138
# 0.02384526091595308
# 0.02314435989671325
# 0.02091430842483512
# 0.02176719563869545
# 0.019735838218592972
# 0.02088907874278111
# 0.019543019387813186
# 0.01981850558528829
# 0.019028329630802993
# 0.01978707822726464
# 0.016796829484204537
# 0.019712586440385014
# 0.019533117153094654
# 0.015773193632069027
# 0.019693824784569946
# 0.013652729053371964
# 0.013597465480092373
# 0.009613337669063943
# 0.005401591556506118
# 0.007266126308662967
# 0.007332133019797614
# 0.0037761677999424864
# 0.006760531678774887
# 0.003161259558588374
# 0.008559489030029887
# 0.005822100066772493
# 0.005387857155902089
# 0.00749848144134469
# 0.0016485833323192653
# 0.0020123854615042036
# 1.5295398726220175e-06
# Negative stress, end of calculation 1 !
# Run 1 finished!!!!!!!!!!!!!!!!!!!

# %%
allCoord_eq20 = []

count = 1
run = 1

for finalFiles in loadedFiles:
    listX = 'xSize_' + str(run)
    listX = []
    listY = 'ySize_' + str(run)
    listY = []    
    listZ = 'zSize_' + str(run)
    listZ = []
    listCoord = 'run_' + str(run)
    listCoord = []
    
    for file in finalFiles:
        df = pd.read_csv(file, skiprows=8, sep=" ", engine='python')
        df = df.dropna(axis=1)
        try:
            df.columns = ['ATOMS id', 'type', 'x', 'y', 'z', 'v_s4', 'v_s5', 'v_s6','v_s14', 'v_s15', 'v_s16']
        except:
            print('Error.')
            print("There is nan in " + str(file))
            break
        if math.isnan(df['x'][0]):
            print("There is nan in " + str(file))
            break
        elif np.sum(df['v_s15'].values)<-0.001 and count > 10:
            print("Negative stress, end of calculation " + str(run) + " !")
            break
        else:
            xLen = np.max(df['x'].values) - np.min(df['x'].values)
            yLen = np.max(df['y'].values) - np.min(df['y'].values)
            zLen = np.max(df['z'].values) - np.min(df['z'].values)
            listX.append(xLen)
            listY.append(yLen)
            listZ.append(zLen)
            print("Length of Y axis is " + str(yLen))
        count += 1
    allCoord_eq20.append([listX, listY, listZ])
    print("Run " + str(run) + " finished!!!!!!!!!!!!!!!!!!!")
    count = 1
    run += 1
# Out:
# Length of Y axis is 199.99089999999998
# Length of Y axis is 201.50399999999996
# Length of Y axis is 203.0352
# Length of Y axis is 204.27139999999997
# Length of Y axis is 205.5226
# Length of Y axis is 206.8177
# Length of Y axis is 208.20390000000003
# Length of Y axis is 209.5518
# Length of Y axis is 210.8853
# Length of Y axis is 212.1577
# Length of Y axis is 213.5362
# Length of Y axis is 214.7584
# Length of Y axis is 216.2013
# Length of Y axis is 217.4946
# Length of Y axis is 218.9123
# Length of Y axis is 220.2277
# Length of Y axis is 221.6682
# Length of Y axis is 222.88599999999997
# Length of Y axis is 224.2076
# Length of Y axis is 225.337
# Length of Y axis is 226.6374
# Length of Y axis is 227.7142
# Length of Y axis is 228.9352
# Length of Y axis is 229.99390000000002
# Length of Y axis is 231.0676
# Length of Y axis is 232.3838
# Length of Y axis is 233.21450000000002
# Length of Y axis is 234.33777
# Length of Y axis is 235.366
# Length of Y axis is 236.40756
# Length of Y axis is 237.37088999999997
# Length of Y axis is 238.43479000000002
# Length of Y axis is 239.25593999999998
# Length of Y axis is 240.31403
# Length of Y axis is 241.24728
# Length of Y axis is 242.27758
# Length of Y axis is 243.08404000000002
# Length of Y axis is 244.06107
# Length of Y axis is 244.93639
# Length of Y axis is 245.77374
# Length of Y axis is 246.71902
# Length of Y axis is 247.55997000000002
# Length of Y axis is 248.46376
# Length of Y axis is 249.40111000000002
# Length of Y axis is 250.33856
# Length of Y axis is 251.11595999999997
# Length of Y axis is 251.95655
# Length of Y axis is 252.757951
# Length of Y axis is 253.607179
# Length of Y axis is 254.48523600000001
# Length of Y axis is 255.31653999999997
# Length of Y axis is 256.07106999999996
# Length of Y axis is 256.8482
# Length of Y axis is 257.69984
# Length of Y axis is 258.37602999999996
# Length of Y axis is 259.16333999999995
# Length of Y axis is 260.04322
# Length of Y axis is 260.75311000000005
# Length of Y axis is 261.51818000000003
# Length of Y axis is 262.38799
# Length of Y axis is 262.99262999999996
# Length of Y axis is 263.79695
# Length of Y axis is 264.56176
# Length of Y axis is 265.28493
# Length of Y axis is 266.05573
# Length of Y axis is 266.60414
# Length of Y axis is 267.4317
# Length of Y axis is 268.15818
# Length of Y axis is 268.89132
# Length of Y axis is 269.75847999999996
# Length of Y axis is 270.23325000000006
# Length of Y axis is 271.08197
# Length of Y axis is 271.67472000000004
# Length of Y axis is 272.38734
# Length of Y axis is 272.90323
# Length of Y axis is 273.80460999999997
# Length of Y axis is 274.5439
# Length of Y axis is 275.1564
# Length of Y axis is 275.7323
# Length of Y axis is 276.5028
# Length of Y axis is 277.0942
# Length of Y axis is 277.7554
# Length of Y axis is 278.3603
# Length of Y axis is 279.0706
# Length of Y axis is 279.69710000000003
# Length of Y axis is 280.3541
# Length of Y axis is 281.03499999999997
# Length of Y axis is 281.6988
# Length of Y axis is 282.4314
# Length of Y axis is 282.8865
# Length of Y axis is 283.57109999999994
# Length of Y axis is 284.20259999999996
# Length of Y axis is 284.8436
# Length of Y axis is 285.3578
# Length of Y axis is 286.0999
# Length of Y axis is 286.6299
# Length of Y axis is 287.1873
# Length of Y axis is 287.91429999999997
# Length of Y axis is 288.38789999999995
# Length of Y axis is 289.1549
# Length of Y axis is 289.6848
# Length of Y axis is 290.2242
# Length of Y axis is 291.034
# Length of Y axis is 291.591
# Length of Y axis is 292.0921
# Length of Y axis is 292.6967
# Length of Y axis is 293.3048
# Length of Y axis is 293.929
# Length of Y axis is 294.462
# Length of Y axis is 295.134
# Length of Y axis is 295.79119999999995
# Length of Y axis is 296.24269999999996
# Length of Y axis is 296.7581
# Length of Y axis is 297.32280000000003
# Length of Y axis is 297.99
# Length of Y axis is 298.54740000000004
# Length of Y axis is 299.0463
# Length of Y axis is 299.68
# Length of Y axis is 300.29630000000003
# Length of Y axis is 300.80539999999996
# Length of Y axis is 301.3947
# Length of Y axis is 301.9233
# Length of Y axis is 302.6797
# Length of Y axis is 303.1652
# Length of Y axis is 303.70579999999995
# Length of Y axis is 304.2449
# Length of Y axis is 304.7882
# Length of Y axis is 305.3626
# Length of Y axis is 305.9419
# Length of Y axis is 306.5394
# Length of Y axis is 307.0399
# Length of Y axis is 307.6617
# Length of Y axis is 308.1633
# Length of Y axis is 308.73589999999996
# Length of Y axis is 309.2363
# Length of Y axis is 309.8779
# Length of Y axis is 310.3925
# Length of Y axis is 311.0029
# Length of Y axis is 311.4585
# Length of Y axis is 312.2758
# Length of Y axis is 312.67999999999995
# Length of Y axis is 313.1569
# Length of Y axis is 313.6734
# Length of Y axis is 314.2584
# Length of Y axis is 314.7277
# Length of Y axis is 315.35040000000004
# Length of Y axis is 315.8853
# Length of Y axis is 316.4154
# Length of Y axis is 317.0023
# Length of Y axis is 317.55240000000003
# Length of Y axis is 318.1816
# Length of Y axis is 318.5432
# Length of Y axis is 319.26009999999997
# Length of Y axis is 319.639
# Length of Y axis is 320.26820000000004
# Length of Y axis is 320.8947
# Length of Y axis is 321.2168
# Length of Y axis is 321.8151
# Length of Y axis is 322.3602
# Length of Y axis is 322.944
# Length of Y axis is 323.4798
# Length of Y axis is 324.0149
# Length of Y axis is 324.53780000000006
# Length of Y axis is 325.0382
# Length of Y axis is 325.6699
# Length of Y axis is 326.23429999999996
# Length of Y axis is 326.6497
# Length of Y axis is 327.15860000000004
# Length of Y axis is 327.722
# Length of Y axis is 328.27299999999997
# Length of Y axis is 328.8357
# Length of Y axis is 329.2552
# Length of Y axis is 329.8754
# Length of Y axis is 330.4634
# Length of Y axis is 330.98679999999996
# Length of Y axis is 331.4805
# Length of Y axis is 332.04319999999996
# Length of Y axis is 332.579
# Negative stress, end of calculation 1 !
# Run 1 finished!!!!!!!!!!!!!!!!!!!

# %%
# print(len(v_s15_1))
# print(len(v_s15_2))
# print(len(v_s15_3))
# print(len(v_s15_4))
# print(len(v_s15_5))

#print(len(allStress_eq20))

# %%
totalBoxSize = 210 * 500 * 200

modelSize1 = allCoord_eq20[0][0][0] * allCoord_eq20[0][1][0] * allCoord_eq20[0][2][0]
#modelSize2 = allCoord_eq20[1][0][0] * allCoord_eq20[1][1][0] * allCoord_eq20[1][2][0]
#modelSize3 = allCoord_eq20[2][0][0] * allCoord_eq20[2][1][0] * allCoord_eq20[2][2][0]
#modelSize4 = allCoord_eq20[3][0][0] * allCoord_eq20[3][1][0] * allCoord_eq20[3][2][0]
#modelSize5 = allCoord_eq20[4][0][0] * allCoord_eq20[4][1][0] * allCoord_eq20[4][2][0]

initialLength1 = allCoord_eq20[0][1][0]
#initialLength2 = allCoord_eq20[1][1][0]
#initialLength3 = allCoord_eq20[2][1][0]
#initialLength4 = allCoord_eq20[3][1][0]
#initialLength5 = allCoord_eq20[4][1][0]


stress1 = [i * totalBoxSize / modelSize1 for i in allStress_eq20[0]]
#stress2 = [i * totalBoxSize / modelSize2 for i in allStress_eq20[1]]
#stress3 = [i * totalBoxSize / modelSize3 for i in allStress_eq20[2]]
#stress4 = [i * totalBoxSize / modelSize4 for i in allStress_eq20[3]]
#stress5 = [i * totalBoxSize / modelSize5 for i in allStress_eq20[4]]
strain1 = [(i - initialLength1)/initialLength1 for i in allCoord_eq20[0][1]]
#strain2 = [(i - initialLength2)/initialLength2 for i in allCoord_eq20[1][1]]
#strain3 = [(i - initialLength3)/initialLength3 for i in allCoord_eq20[2][1]]
#strain4 = [(i - initialLength4)/initialLength4 for i in allCoord_eq20[3][1]]
#strain5 = [(i - initialLength5)/initialLength5 for i in allCoord_eq20[4][1]]

# %%
filepathout = 'C:/Users/Berry/Documents/SS_curve_冠廷/'

run = 1
#stressStrain = [[strain1, stress1], [strain2, stress2], [strain3, stress3], [strain4, stress4], [strain5, stress5]]
stressStrain = [[strain1, stress1]]
for runs in stressStrain:
    wb = Workbook()
    ws = wb.active
    for s in range(len(runs[0])):
        ws.append([runs[0][s], runs[1][s]])
    wb.save(filepathout + fout + str(run) + '.xlsx')
    run += 1

# %%
plt.figure(dpi = 900)
plt.title('Stress-Strain (%s)' % (fout[:-1]) )
plt.plot(strain1, stress1, label = "rnd = 1")
#plt.plot(strain2, stress2, label = "rnd = 2")
#plt.plot(strain3, stress3, label = "rnd = 3")
#plt.plot(strain4, stress4, label = "rnd = 4")
#plt.plot(strain5, stress5, label = "rnd = 5")
plt.legend(loc = 'best')
plt.xlabel('strain')
plt.ylabel('stress')
plt.grid()
plt.savefig(filepathout + str(fout[:-1]) + '.png')
plt.show()

# %%
#Strain_avg = np.mean([   strain1[-1] ,strain2[-1],strain3[-1],strain4[-1],strain5[-1]   ])
#Strain_std = np.std([   strain1[-1] ,strain2[-1],strain3[-1],strain4[-1] ,strain5[-1]   ])
#Stress_avg = np.mean([   max(stress1),max(stress2),max(stress3) ,max(stress4) ,max(stress5)   ])
#Stress_std = np.std([   max(stress1),max(stress2),max(stress3) ,max(stress4) ,max(stress5)   ])

print('Strain:',strain1[-1])
print('Stress:',max(stress1))
# Out:
# Strain: 0.6629706651652653
# Stress: 6.276123729674893

# %%
# if np.nan in xarr:
#     print("Ya")

# print(math.isnan(df['x'][0]))
# print(np.isin(xarr[0], xarr).any())
# print(xarr)
# print(type(xarr[0]))

# %%
# test = df['x'][0]
# np.isnan(test)

# %%
# mainlist = []
# for i in range(1,6):
#     a = 'v_s15__'
#     b = str(i)
#     c = a+b
#     print(c)
#     c = []
#     for j in range (10):
#         c.append(j)
#     mainlist.append((c))
    
# print(mainlist)
# print(mainlist[0])

# %%
# v_s15_1 = []
# v_s15_2 = []
# v_s15_3 = []
# v_s15_4 = []
# v_s15_5 = []
# #length1 = []
# #length2 = []
# #length3 = []
# #length4 = []
# #length5 = []
# count = 1

# for filename in final_files1:
#     #df1 = pd.read_csv(filename, skiprows = 6, nrows = 1, header = None, engine='python')
#     #print(df1)
#     #st1 = [(float)(df1[0][0].split(' ')[0]), (float)(df1[0][0].split(' ')[1])]
#     #length1.append(st1[1] - st1[0])
#     df11 = pd.read_csv(filename, skiprows=8, sep=" ", engine='python')
#     #print(df)
#     df11 = df11.dropna(axis=1)
#     try:
#         df11.columns = ['ATOMS id', 'type', 'x', 'y', 'z', 'v_s4', 'v_s5', 'v_s6','v_s14', 'v_s15', 'v_s16']
#     except:
#         print('Error.')
#         print("There is nan in " + str(filename))
#         break
#     s_df11 = df11.astype(str)
#     if sum(df11['v_s15'])<-0.001 and count > 10:
#         print("Negative stress, end of calculation 1.")
#         break
#     #elif s_df11["v_s15"].str.contains("nan").any() or s_df11["v_s15"].str.contains("-nan").any():
#     elif any("nan" in s15 for s15 in s_df11['v_s15']):
#         print("Nan exists in file " + str(filename))
#         break
#     else:
#         ans1 = sum(df11['v_s15'])
#         print(ans1)
#         v_s15_1.append(ans1)
#     count += 1
        
# print("First Done!")
# count = 1

# for filename in final_files2:
#     #df2 = pd.read_csv(filename, skiprows = 6, nrows = 1, header = None, engine='python')
#     #print(df2)
#     #st2 = [(float)(df2[0][0].split(' ')[0]), (float)(df2[0][0].split(' ')[1])]
#     #length2.append(st2[1] - st2[0])
#     df22 = pd.read_csv(filename, skiprows=8, sep=" ", engine='python')
#     #print(df)
#     df22 = df22.dropna(axis=1)
#     try:
#         df22.columns = ['ATOMS id', 'type', 'x', 'y', 'z', 'v_s4', 'v_s5', 'v_s6','v_s14', 'v_s15', 'v_s16']
#     except:
#         print('Error.')
#         print("There is nan in " + str(filename))
#         break
#     s_df22 = df22.astype(str)
#     if sum(df22['v_s15'])<-0.001 and count > 10:
#         print("Negative stress, end of calculation 2.")
#         break
#     #elif s_df22["v_s15"].str.contains("nan").any() or s_df22["v_s15"].str.contains("-nan").any():
#     elif any("nan" in s15 for s15 in s_df22['v_s15']):
#         print("Nan exists in file " + str(filename))
#         break
#     else:
#         ans2 = sum(df22['v_s15'])
#         print(ans2)
#         v_s15_2.append(ans2)
#     count += 1
        
# print("Second Done!")
# count = 1

# for filename in final_files3:
#     #df3 = pd.read_csv(filename, skiprows = 6, nrows = 1, header = None, engine='python')
#     #print(df3)
#     #st3 = [(float)(df3[0][0].split(' ')[0]), (float)(df3[0][0].split(' ')[1])]
#     #length3.append(st3[1] - st3[0])
#     df33 = pd.read_csv(filename, skiprows=8, sep=" ", engine='python')
#     #print(df)
#     df33 = df33.dropna(axis=1)
#     try:
#         df33.columns = ['ATOMS id', 'type', 'x', 'y', 'z', 'v_s4', 'v_s5', 'v_s6','v_s14', 'v_s15', 'v_s16']
#     except:
#         print('Error.')
#         print("There is nan in " + str(filename))
#         break
#     s_df33 = df33.astype(str)
#     if sum(df33['v_s15'])<-0.001 and count > 10:
#         print("Negative stress, end of calculation 3.")
#         break
#     #elif s_df33["v_s15"].str.contains("nan").any() or s_df33["v_s15"].str.contains("-nan").any():
#     elif any("nan" in s15 for s15 in s_df33['v_s15']):
#         print("Nan exists in file " + str(filename))
#         break
#     else:
#         ans3 = sum(df33['v_s15'])
#         print(ans3)
#         v_s15_3.append(ans3)
#     count += 1
        
# print("Third Done!")
# count = 1

# for filename in final_files4:
#     #df4 = pd.read_csv(filename, skiprows = 6, nrows = 1, header = None, engine='python')
#     #print(df4)
#     #st4 = [(float)(df4[0][0].split(' ')[0]), (float)(df4[0][0].split(' ')[1])]
#     #length4.append(st4[1] - st4[0])
#     df44 = pd.read_csv(filename, skiprows=8, sep=" ", engine='python')
#     #print(df)
#     df44 = df44.dropna(axis=1)
#     try:
#         df44.columns = ['ATOMS id', 'type', 'x', 'y', 'z', 'v_s4', 'v_s5', 'v_s6','v_s14', 'v_s15', 'v_s16']
#     except:
#         print('Error.')
#         print("There is nan in " + str(filename))
#         break
#     s_df44 = df44.astype(str)
#     if sum(df44['v_s15'])<-0.001 and count > 10:
#         print("Negative stress, end of calculation 4.")
#         break
#     #elif s_df44["v_s15"].str.contains("nan").any() or s_df4["v_s15"].str.contains("-nan").any():
#     elif any("nan" in s15 for s15 in s_df44['v_s15']):
#         print("Nan exists in file " + str(filename))
#         break
#     else:
#         ans4 = sum(df44['v_s15'])
#         print(ans4)
#         v_s15_4.append(ans4)
#     count += 1
    
# print("Fourth Done!")
# count = 1

# for filename in final_files5:
#     #df5 = pd.read_csv(filename, skiprows = 6, nrows = 1, header = None, engine='python')
#     #print(df2)
#     #st5 = [(float)(df5[0][0].split(' ')[0]), (float)(df5[0][0].split(' ')[1])]
#     #length5.append(st5[1] - st5[0])
#     df55 = pd.read_csv(filename, skiprows=8, sep=" ", engine='python')
#     #print(df)
#     df55 = df55.dropna(axis=1)
#     try:
#         df55.columns = ['ATOMS id', 'type', 'x', 'y', 'z', 'v_s4', 'v_s5', 'v_s6','v_s14', 'v_s15', 'v_s16']
#     except:
#         print('Error.')
#         print("There is nan in " + str(filename))
#         break
#     s_df55 = df55.astype(str)
#     if any("nan" in s15 for s15 in s_df55['v_s15']):
#         print("Nan exists in file " + str(filename))
#         break
#     elif sum(df55['v_s15'])<-0.001 and count > 10:
#         print("Negative stress, end of calculation 5.")
#         break
#     #elif s_df55["v_s15"].str.contains("nan").any() or s_df55["v_s15"].str.contains("-nan").any():
#     else:
#         ans5 = sum(df55['v_s15'])
#         print(ans5)
#         v_s15_5.append(ans5)
#     count += 1
        
# print("Fifth Done!")

# %%
# xSize1 = []
# ySize1 = []
# zSize1 = []

# xSize2 = []
# ySize2 = []
# zSize2 = []

# xSize3 = []
# ySize3 = []
# zSize3 = []

# xSize4 = []
# ySize4 = []
# zSize4 = []

# xSize5 = []
# ySize5 = []
# zSize5 = []

# # strain1 = []
# # strain2 = []
# # strain3 = []
# # strain4 = []
# # strain5 = []

# count = 1

# ###  1
# for filename in final_files1:
#     df11 = pd.read_csv(filename, skiprows=8, sep=" ", engine='python')
#     #print(df11)
#     df11 = df11.dropna(axis=1)
#     #print(df11.head())
#     try:
#         df11.columns = ['ATOMS id', 'type', 'x', 'y', 'z', 'v_s4', 'v_s5', 'v_s6','v_s14', 'v_s15', 'v_s16']
#     except:
#         print('Error.')
#         print("There is nan in " + str(filename))
#         break
#     #s_df11 = df11.astype(str)
#     #if pd.isnull(df11['v_s15']).any():
#     #any("nan" in s15 for s15 in s_df11['v_s15']):
#     arr1 = df11['x'].values
#     if math.isnan(df11['x'][0]):
#     #if np.isin(arr1, np.nan).any():
#         print("There is nan in " + str(filename))
#         break        
#     elif sum(df11['v_s15'])<-0.001 and count > 10:
#         print("Negative stress in run 1")
#         break
#     else:
# #         xMin = min(df11['x'])
# #         xMax = max(df11['x'])
# #         yMin = min(df11['y'])
# #         yMax = max(df11['y'])
# #         zMin = min(df11['z'])
# #         zMax = max(df11['z'])
#         xLen = max(df11['x']) - min(df11['x'])
#         yLen = max(df11['y']) - min(df11['y'])
#         zLen = max(df11['z']) - min(df11['z'])
#         xSize1.append(xLen)
#         ySize1.append(yLen)
#         zSize1.append(zLen)
#         print("Length of Y axis is " + str(yLen))
#     #print("Length of x is %.3f" %xLen)
#     #print("Length of y is %.3f" %yLen)
#     #print("Length of z is %.3f" %zLen)
#     count += 1
# print("Run 1 finished!")
# count = 1    
    
# ###  2    
# for filename in final_files2:
#     df22 = pd.read_csv(filename, skiprows=8, sep=" ", engine='python')
#     #print(df)
#     df22 = df22.dropna(axis=1)
#     #print(df)
#     try:
#         df22.columns = ['ATOMS id', 'type', 'x', 'y', 'z', 'v_s4', 'v_s5', 'v_s6','v_s14', 'v_s15', 'v_s16']
#     except:
#         print('Error.')
#         print("There is nan in " + str(filename))
#         break
        
#     #s_df22 = df22.astype(str)
#     arr2 = df22['x'].values
#     #if np.isin(arr2, np.nan).any():
    
#     if math.isnan(df22['x'][0]):
#         print("There is nan in " + str(filename))
#         break
#     elif np.sum(df22['v_s15'].values)<-0.001 and count > 10:
#         print("Negative stress in run 2")
#         break
#     else:
#         xLen = np.max(df22['x'].values) - np.min(df22['x'].values)
#         yLen = np.max(df22['y'].values) - np.min(df22['y'].values)
#         zLen = np.max(df22['z'].values) - np.min(df22['z'].values)
#         xSize2.append(xLen)
#         ySize2.append(yLen)
#         zSize2.append(zLen)
#         print("Length of Y axis is " + str(yLen))
# print("Run 2 finished!")
# count = 1

# ###  3  
# for filename in final_files3:
#     df33 = pd.read_csv(filename, skiprows=8, sep=" ", engine='python')
#     #print(df)
#     df33 = df33.dropna(axis=1)
#     try:
#         df33.columns = ['ATOMS id', 'type', 'x', 'y', 'z', 'v_s4', 'v_s5', 'v_s6','v_s14', 'v_s15', 'v_s16']
#     except:
#         print('Error.')
#         print("There is nan in " + str(filename))
#         break
#     arr3 = df33['x'].values
#     #if np.isin(arr3, np.nan).any():
#     if math.isnan(df33['x'][0]):
#         print("There is nan in " + str(filename))
#         break
#     elif sum(df33['v_s15'])<-0.001 and count > 10:
#         print("Negative stress in run 3")
#         break
#     else:
#         xLen = max(df33['x']) - min(df33['x'])
#         yLen = max(df33['y']) - min(df33['y'])
#         zLen = max(df33['z']) - min(df33['z'])
#         xSize3.append(xLen)
#         ySize3.append(yLen)
#         zSize3.append(zLen)
#         print("Length of Y axis is " + str(yLen))
# print("Run 3 finished!")
# count = 1

# ###  4
# for filename in final_files2:
#     df44 = pd.read_csv(filename, skiprows=8, sep=" ", engine='python')
#     #print(df)
#     df44 = df44.dropna(axis=1)
#     try:
#         df44.columns = ['ATOMS id', 'type', 'x', 'y', 'z', 'v_s4', 'v_s5', 'v_s6','v_s14', 'v_s15', 'v_s16']
#     except:
#         print('Error.')
#         print("There is nan in " + str(filename))
#         break
#     arr4 = df44['x'].values
#     #if np.isin(arr4, np.nan).any():
#     if math.isnan(df44['x'][0]):
#         print("There is nan in " + str(filename))
#         break
#     elif sum(df44['v_s15'])<-0.001 and count > 10:
#         print("Negative stress in run 4")
#         break
#     else:
#         xLen = max(df44['x']) - min(df44['x'])
#         yLen = max(df44['y']) - min(df44['y'])
#         zLen = max(df44['z']) - min(df44['z'])
#         xSize4.append(xLen)
#         ySize4.append(yLen)
#         zSize4.append(zLen)
#         print("Length of Y axis is " + str(yLen))
# print("Run 4 finished!")
# count = 1

# ###  5
# for filename in final_files5:
#     df55 = pd.read_csv(filename, skiprows=8, sep=" ", engine='python')
#     #print(df)
#     df55 = df55.dropna(axis=1)
#     try:
#         df55.columns = ['ATOMS id', 'type', 'x', 'y', 'z', 'v_s4', 'v_s5', 'v_s6','v_s14', 'v_s15', 'v_s16']
#     except:
#         print('Error.')
#         print("There is nan in " + str(filename))
#         break
#     arr5 = df55['x'].values
#     #if np.isin(arr5, np.nan).any():
#     if math.isnan(df55['x'][0]):
#         print("There is nan in " + str(filename))
#         break
#     elif sum(df55['v_s15'])<-0.001 and count > 10:
#         print("Negative stress in run 5")
#         break
#     else:
#         xLen = max(df55['x']) - min(df55['x'])
#         yLen = max(df55['y']) - min(df55['y'])
#         zLen = max(df55['z']) - min(df55['z'])
#         xSize5.append(xLen)
#         ySize5.append(yLen)
#         zSize5.append(zLen)
#         print("Length of Y axis is " + str(yLen))
# print("Run 5 finished!")
