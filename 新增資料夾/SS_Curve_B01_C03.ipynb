# %%
import pandas as pd
import numpy as np
import glob
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
from openpyxl import Workbook
#from scipy.interpolate import interpld
from scipy.interpolate import spline
import math

# %%
fout = 'BO1_C03_'
filepath1 = 'H:/HEA/Finished/C03_BO1_2345674'
#filepath2 = 'H:/HEA/Finished/C01_BO1_2345675'
#filepath3 = 'H:/HEA/Finished/C01_BO1_2345676'
#filepath4 = 'H:/HEA/Finished/C01_BO1_2345677'
#filepath5 = 'H:/HEA/Finished/C01_BO1_2345678'
# filepath1 = 'C:/Users/Tim.Jason-PC/Desktop/HEY/研究交接資料/fraction_of_Mn/Co23Ni23Cr23Fe23Mn8_110_modify/1_1500K/'
# filepath2 = 'C:/Users/Tim.Jason-PC/Desktop/HEY/研究交接資料/Fe/Fe0/20150901_100800/2_tension_1e-3_300K_sss_fracture_4/'
# filepath3 = 'C:/Users/Tim.Jason-PC/Desktop/HEY/研究交接資料/fraction_of_Mn/co25ni25cr25fe25_110_modify/20150901_100800/2_tension_1e-3_300K_sss_fracture_4/'
# filepath4 = 'C:/Users/Tim.Jason-PC/Desktop/HEY/研究交接資料/fraction_of_Mn/Co23Ni23Cr23Fe23Mn8_110_modify/1_1500K/'
# filepath5 = 'C:/Users/Tim.Jason-PC/Desktop/HEY/研究交接資料/Fe/Fe0/20150901_100800/2_tension_1e-3_300K_sss_fracture_4/'
#filepath = 'D:/tensile_md/test/real_final3/normal/'

all_files1 = glob.glob(filepath1 + '/dump/eq20_uniaxial.mid_convert.*')
#all_files2 = glob.glob(filepath2 + '/dump/eq20_uniaxial.mid_convert.*')
#all_files3 = glob.glob(filepath3 + '/dump/eq20_uniaxial.mid_convert.*')
#all_files4 = glob.glob(filepath4 + '/dump/eq20_uniaxial.mid_convert.*')
#all_files5 = glob.glob(filepath5 + '/dump/eq20_uniaxial.mid_convert.*')

files_number1 = [[file, (int)(file.split('.')[-1])] for file in all_files1]
#files_number2 = [[file, (int)(file.split('.')[-1])] for file in all_files2]
#files_number3 = [[file, (int)(file.split('.')[-1])] for file in all_files3]
#files_number4 = [[file, (int)(file.split('.')[-1])] for file in all_files4]
#files_number5 = [[file, (int)(file.split('.')[-1])] for file in all_files5]

sort_files1 = sorted(files_number1, key=lambda x: x[1])
#sort_files2 = sorted(files_number2, key=lambda x: x[1])
#sort_files3 = sorted(files_number3, key=lambda x: x[1])
#sort_files4 = sorted(files_number4, key=lambda x: x[1])
#sort_files5 = sorted(files_number5, key=lambda x: x[1])

final_files1 = [x[0] for x in sort_files1]
#final_files2 = [x[0] for x in sort_files2]
#final_files3 = [x[0] for x in sort_files3]
#final_files4 = [x[0] for x in sort_files4]
#final_files5 = [x[0] for x in sort_files5]
print(final_files1)
#print(final_files2)
#print(final_files3)
#print(final_files4)
#print(final_files5)


#print(all_files[1])
#print(files_number[1])
#print(sort_files[1])
#print(final_files1)
#print(final_files2)
#print(final_files3)
# Out:
/C03_BO1_2345674/dump\\eq20_uniaxial.mid_convert.43000', 'H:/HEA/Finished/C03_BO1_2345674/dump\\eq20_uniaxial.mid_convert.44000', 'H:/HEA/Finished/C03_BO1_2345674/dump\\eq20_uniaxial.mid_convert.45000', 'H:/HEA/Finished/C03_BO1_2345674/dump\\eq20_uniaxial.mid_convert.46000', 'H:/HEA/Finished/C03_BO1_2345674/dump\\eq20_uniaxial.mid_convert.47000', 'H:/HEA/Finished/C03_BO1_2345674/dump\\eq20_uniaxial.mid_convert.48000', 'H:/HEA/Finished/C03_BO1_2345674/dump\\eq20_uniaxial.mid_convert.49000', 'H:/HEA/Finished/C03_BO1_2345674/dump\\eq20_uniaxial.mid_convert.50000', 'H:/HEA/Finished/C03_BO1_2345674/dump\\eq20_uniaxial.mid_convert.51000', 'H:/HEA/Finished/C03_BO1_2345674/dump\\eq20_uniaxial.mid_convert.52000', 'H:/HEA/Finished/C03_BO1_2345674/dump\\eq20_uniaxial.mid_convert.53000', 'H:/HEA/Finished/C03_BO1_2345674/dump\\eq20_uniaxial.mid_convert.5400 ...

# %%
allStress_eq20 = []

count = 1
run = 1

for finalFiles in loadedFiles:
    listName = 'v_s15__' + str(run)
    listName = []
    
    for file in finalFiles:
        df = pd.read_csv(file, skiprows=8, sep=" ", engine='python')
        df = df.dropna(axis=1)
        try:
            df.columns = ['ATOMS id', 'type', 'x', 'y', 'z', 'v_s4', 'v_s5', 'v_s6','v_s14', 'v_s15', 'v_s16']
        except:
            print('Error.')
            print("There is nan in " + str(file))
            break
        s_df = df.astype(str)
        if sum(df['v_s15'])<-0.001 and count > 10:
            print("Negative stress, end of calculation " + str(run) + " !")
            break
        #elif s_df11["v_s15"].str.contains("nan").any() or s_df11["v_s15"].str.contains("-nan").any():
        elif any("nan" in s15 for s15 in s_df['v_s15']):
            print("Nan exists in file " + str(file))
            break
        else:
            ans = sum(df['v_s15'])
            print(ans)
            listName.append(ans)
        count += 1
    allStress_eq20.append(listName)
    print("Run " + str(run) + " finished!!!!!!!!!!!!!!!!!!!")
    count = 1
    run += 1
# Out:
# -0.0005688667808461832
# 0.03015953633990393
# 0.03244901808499914
# 0.05886278051837226
# 0.07882577887330201
# 0.10183139792536436
# 0.1281140893052998
# 0.15220276730043744
# 0.1836744495096579
# 0.20581352974234368
# 0.2357823577978846
# 0.24702048359229725
# 0.26211578432961197
# 0.25937246941530945
# 0.24940817779279456
# 0.22728438609849028
# 0.21003414219125763
# 0.19322188620013986
# 0.18686945278613987
# 0.18426616986954872
# 0.18705881524686868
# 0.18357368275683292
# 0.18535829163360884
# 0.18521389943364772
# 0.18505977833463785
# 0.18888201002463506
# 0.19099001749276845
# 0.1927168903692798
# 0.19357023221414663
# 0.19930165866395008
# 0.2015136508727701
# 0.20308755683992696
# 0.20600212356055916
# 0.21081518230513127
# 0.21641796767501245
# 0.21971393434235323
# 0.2290424641918671
# 0.23154878197549103
# 0.2396382262092449
# 0.24177282165411085
# 0.2507815450774347
# 0.2565488415431321
# 0.26058208199192906
# 0.07769345954150177
# 0.07537249717979666
# 0.07391307190951621
# 0.07622501239942021
# 0.076061761122774
# 0.07380720922407101
# 0.07053043789082197
# 0.06965849750575312
# 0.06584401664958925
# 0.0639388720420847
# 0.06263131804105024
# 0.058702830776899965
# 0.05973900363119231
# 0.05413806904010071
# 0.053942931980384495
# 0.05390156842009329
# 0.05157865765119363
# 0.05132986275015526
# 0.048553644456470445
# 0.050240877310942865
# 0.049726818676844455
# 0.050039664752386595
# 0.052606492867573615
# 0.052437490272605365
# 0.05120872739921616
# 0.04912565999916365
# 0.047042800470550844
# 0.04775560256035694
# 0.04533736642044045
# 0.0444158990504699
# 0.042549064880754425
# 0.039111764366789856
# 0.0415945141866335
# 0.03923680421689933
# 0.036542837334390524
# 0.03748035450398609
# 0.037127930194645976
# 0.03783732090065722
# 0.032295669206990986
# 0.034974940572887143
# 0.03142367716942125
# 0.03283218216130007
# 0.03220669300440898
# 0.030094640929732568
# 0.030483493537712857
# 0.0326164401384591
# 0.031181058402639815
# 0.025959722742295882
# 0.02567844850091698
# 0.022595086873444307
# 0.022065901867744056
# 0.021372821681752346
# 0.024630398689187524
# 0.022841008291205136
# 0.02472869605150769
# 0.02393979466166395
# 0.026661126315634654
# 0.024558788695566925
# 0.023609888862354322
# 0.023758165540936824
# 0.02296799663182043
# 0.02154537497073894
# 0.020949575664589302
# 0.019363295481011036
# 0.019655300798197998
# 0.0175072093139181
# 0.015714651883795578
# 0.01597629949090528
# 0.013475761147670028
# 0.013314170683605095
# 0.009018971646550415
# 0.010201797713937422
# 0.008118565759002744
# 0.008764630821402093
# 0.010290715451419054
# 0.010228073432311512
# 0.007991682475562995
# 0.009829267792693839
# 0.012676432379166658
# 0.009019273729100098
# 0.014546601580345634
# 0.009451677623120708
# 0.009936504580061454
# 0.006679322174648273
# 0.007347872243523156
# 0.008058226771343328
# 0.003461670497821256
# 0.003634849007176921
# 0.003098510237810024
# 0.0012180258625787298
# 0.0032925242279298853
# 0.0014920240177478863
# 0.002721474162988484
# 0.003630820332044107
# 0.001468146750565388
# Negative stress, end of calculation 1 !
# Run 1 finished!!!!!!!!!!!!!!!!!!!

# %%
allCoord_eq20 = []

count = 1
run = 1

for finalFiles in loadedFiles:
    listX = 'xSize_' + str(run)
    listX = []
    listY = 'ySize_' + str(run)
    listY = []    
    listZ = 'zSize_' + str(run)
    listZ = []
    listCoord = 'run_' + str(run)
    listCoord = []
    
    for file in finalFiles:
        df = pd.read_csv(file, skiprows=8, sep=" ", engine='python')
        df = df.dropna(axis=1)
        try:
            df.columns = ['ATOMS id', 'type', 'x', 'y', 'z', 'v_s4', 'v_s5', 'v_s6','v_s14', 'v_s15', 'v_s16']
        except:
            print('Error.')
            print("There is nan in " + str(file))
            break
        if math.isnan(df['x'][0]):
            print("There is nan in " + str(file))
            break
        elif np.sum(df['v_s15'].values)<-0.001 and count > 10:
            print("Negative stress, end of calculation " + str(run) + " !")
            break
        else:
            xLen = np.max(df['x'].values) - np.min(df['x'].values)
            yLen = np.max(df['y'].values) - np.min(df['y'].values)
            zLen = np.max(df['z'].values) - np.min(df['z'].values)
            listX.append(xLen)
            listY.append(yLen)
            listZ.append(zLen)
            print("Length of Y axis is " + str(yLen))
        count += 1
    allCoord_eq20.append([listX, listY, listZ])
    print("Run " + str(run) + " finished!!!!!!!!!!!!!!!!!!!")
    count = 1
    run += 1
# Out:
# Length of Y axis is 199.995
# Length of Y axis is 201.593
# Length of Y axis is 202.8571
# Length of Y axis is 204.25019999999998
# Length of Y axis is 205.6167
# Length of Y axis is 206.82599999999996
# Length of Y axis is 208.2891
# Length of Y axis is 209.6289
# Length of Y axis is 211.14690000000002
# Length of Y axis is 212.2345
# Length of Y axis is 213.61270000000002
# Length of Y axis is 214.8916
# Length of Y axis is 216.4074
# Length of Y axis is 217.56070000000003
# Length of Y axis is 218.90259999999998
# Length of Y axis is 220.3454
# Length of Y axis is 221.58780000000002
# Length of Y axis is 222.6889
# Length of Y axis is 224.02309999999997
# Length of Y axis is 225.2011
# Length of Y axis is 226.6401
# Length of Y axis is 227.6281
# Length of Y axis is 228.80079999999998
# Length of Y axis is 230.0255
# Length of Y axis is 231.18560000000002
# Length of Y axis is 232.0897
# Length of Y axis is 233.2437
# Length of Y axis is 234.27578
# Length of Y axis is 235.3832
# Length of Y axis is 236.51943000000003
# Length of Y axis is 237.45805000000001
# Length of Y axis is 238.57166
# Length of Y axis is 239.42624
# Length of Y axis is 240.47311000000002
# Length of Y axis is 241.49084
# Length of Y axis is 242.52106999999998
# Length of Y axis is 243.49304
# Length of Y axis is 244.44366
# Length of Y axis is 245.55034
# Length of Y axis is 246.30929
# Length of Y axis is 247.34739000000002
# Length of Y axis is 248.33226000000002
# Length of Y axis is 249.20848999999998
# Length of Y axis is 250.14387
# Length of Y axis is 251.11091
# Length of Y axis is 251.97050000000002
# Length of Y axis is 252.950714
# Length of Y axis is 253.862948
# Length of Y axis is 254.764662
# Length of Y axis is 255.545488
# Length of Y axis is 256.49643
# Length of Y axis is 257.3299
# Length of Y axis is 258.30065
# Length of Y axis is 259.1482
# Length of Y axis is 259.99438
# Length of Y axis is 261.06289999999996
# Length of Y axis is 261.69622
# Length of Y axis is 262.64345000000003
# Length of Y axis is 263.43682
# Length of Y axis is 264.27318
# Length of Y axis is 265.23065
# Length of Y axis is 265.90523
# Length of Y axis is 266.53578
# Length of Y axis is 267.51937
# Length of Y axis is 268.24507
# Length of Y axis is 268.79976
# Length of Y axis is 269.73401
# Length of Y axis is 270.4892
# Length of Y axis is 271.25416
# Length of Y axis is 271.99388
# Length of Y axis is 272.71158
# Length of Y axis is 273.26937
# Length of Y axis is 274.12190000000004
# Length of Y axis is 274.8593
# Length of Y axis is 275.4932
# Length of Y axis is 276.1562
# Length of Y axis is 276.94239999999996
# Length of Y axis is 277.6745
# Length of Y axis is 278.4013
# Length of Y axis is 279.0034
# Length of Y axis is 279.7073
# Length of Y axis is 280.4289
# Length of Y axis is 281.1386
# Length of Y axis is 281.8339
# Length of Y axis is 282.41600000000005
# Length of Y axis is 283.0889
# Length of Y axis is 283.7486
# Length of Y axis is 284.3966
# Length of Y axis is 285.0877
# Length of Y axis is 285.8648
# Length of Y axis is 286.49710000000005
# Length of Y axis is 287.1599
# Length of Y axis is 287.72090000000003
# Length of Y axis is 288.3771
# Length of Y axis is 288.9694
# Length of Y axis is 289.6816
# Length of Y axis is 290.3629
# Length of Y axis is 290.9074
# Length of Y axis is 291.4815
# Length of Y axis is 292.31539999999995
# Length of Y axis is 292.90020000000004
# Length of Y axis is 293.57280000000003
# Length of Y axis is 294.0976
# Length of Y axis is 294.769
# Length of Y axis is 295.3364
# Length of Y axis is 295.9164
# Length of Y axis is 296.8025
# Length of Y axis is 297.36650000000003
# Length of Y axis is 297.9103
# Length of Y axis is 298.7996
# Length of Y axis is 299.1039
# Length of Y axis is 299.8219
# Length of Y axis is 300.21099999999996
# Length of Y axis is 300.894
# Length of Y axis is 301.42199999999997
# Length of Y axis is 302.22870000000006
# Length of Y axis is 302.8659
# Length of Y axis is 303.3334
# Length of Y axis is 303.8898
# Length of Y axis is 304.3685
# Length of Y axis is 304.9562
# Length of Y axis is 305.61469999999997
# Length of Y axis is 306.2544
# Length of Y axis is 306.856
# Length of Y axis is 307.3009
# Length of Y axis is 307.86469999999997
# Length of Y axis is 308.53159999999997
# Length of Y axis is 308.94780000000003
# Length of Y axis is 309.63939999999997
# Length of Y axis is 310.2012
# Length of Y axis is 310.6373
# Length of Y axis is 311.3877
# Length of Y axis is 311.90819999999997
# Length of Y axis is 312.4593
# Length of Y axis is 313.01020000000005
# Length of Y axis is 313.66839999999996
# Length of Y axis is 314.2596
# Length of Y axis is 314.66700000000003
# Length of Y axis is 315.1409
# Length of Y axis is 315.74469999999997
# Length of Y axis is 316.25829999999996
# Length of Y axis is 316.8411
# Length of Y axis is 317.3872
# Length of Y axis is 317.8718
# Length of Y axis is 318.43800000000005
# Length of Y axis is 318.94930000000005
# Length of Y axis is 319.51009999999997
# Length of Y axis is 320.11199999999997
# Length of Y axis is 320.66040000000004
# Length of Y axis is 321.2988
# Length of Y axis is 321.6345
# Length of Y axis is 322.2669
# Length of Y axis is 322.8621
# Length of Y axis is 323.3496
# Length of Y axis is 323.88829999999996
# Length of Y axis is 324.3374
# Length of Y axis is 324.81050000000005
# Length of Y axis is 325.55600000000004
# Length of Y axis is 326.065
# Length of Y axis is 326.48969999999997
# Length of Y axis is 327.03900000000004
# Length of Y axis is 327.60220000000004
# Length of Y axis is 327.9739
# Length of Y axis is 328.553
# Length of Y axis is 329.09569999999997
# Length of Y axis is 329.5675
# Length of Y axis is 330.27909999999997
# Length of Y axis is 330.6481
# Length of Y axis is 331.1347
# Length of Y axis is 331.6885
# Length of Y axis is 332.22249999999997
# Length of Y axis is 332.80999999999995
# Length of Y axis is 333.2809
# Length of Y axis is 333.69169999999997
# Length of Y axis is 334.3319
# Length of Y axis is 334.8673
# Length of Y axis is 335.41420000000005
# Length of Y axis is 335.8873
# Length of Y axis is 336.2598
# Length of Y axis is 336.7523
# Length of Y axis is 337.32169999999996
# Length of Y axis is 337.7496
# Length of Y axis is 338.4139
# Length of Y axis is 338.80109999999996
# Length of Y axis is 339.4236
# Length of Y axis is 339.8185
# Length of Y axis is 340.355
# Length of Y axis is 340.9075
# Length of Y axis is 341.25239999999997
# Length of Y axis is 341.79339999999996
# Length of Y axis is 342.39209999999997
# Length of Y axis is 342.7849
# Length of Y axis is 343.3228
# Length of Y axis is 343.74519999999995
# Length of Y axis is 344.2151
# Length of Y axis is 344.86789999999996
# Length of Y axis is 345.271
# Length of Y axis is 345.723
# Length of Y axis is 346.21630000000005
# Length of Y axis is 346.7662
# Length of Y axis is 347.1749
# Length of Y axis is 347.6397
# Length of Y axis is 348.17900000000003
# Length of Y axis is 348.6481
# Length of Y axis is 349.2419
# Length of Y axis is 349.7301
# Length of Y axis is 350.0838
# Length of Y axis is 350.6797
# Length of Y axis is 351.09299999999996
# Length of Y axis is 351.6414
# Length of Y axis is 352.08209999999997
# Length of Y axis is 352.6232
# Length of Y axis is 353.15200000000004
# Length of Y axis is 353.6981
# Length of Y axis is 354.0611
# Length of Y axis is 354.51869999999997
# Length of Y axis is 354.9449
# Length of Y axis is 355.4483
# Length of Y axis is 356.031
# Length of Y axis is 356.3786
# Length of Y axis is 356.9266
# Length of Y axis is 357.47769999999997
# Length of Y axis is 357.8865
# Length of Y axis is 358.2444
# Length of Y axis is 358.7742
# Length of Y axis is 359.23550000000006
# Length of Y axis is 359.68670000000003
# Length of Y axis is 360.1535
# Length of Y axis is 360.6156
# Length of Y axis is 361.1277
# Length of Y axis is 361.70489999999995
# Length of Y axis is 362.075
# Length of Y axis is 362.4839
# Length of Y axis is 362.9606
# Length of Y axis is 363.39639999999997
# Length of Y axis is 363.8963
# Length of Y axis is 364.4138
# Length of Y axis is 364.9427
# Length of Y axis is 365.2907
# Length of Y axis is 365.7624
# Length of Y axis is 366.27529999999996
# Length of Y axis is 366.66229999999996
# Length of Y axis is 367.19870000000003
# Length of Y axis is 367.7194
# Length of Y axis is 368.1887
# Length of Y axis is 368.68510000000003
# Length of Y axis is 369.0808
# Length of Y axis is 369.4501
# Length of Y axis is 369.9042
# Length of Y axis is 370.4854
# Length of Y axis is 370.9987
# Length of Y axis is 371.43820000000005
# Length of Y axis is 371.8057
# Length of Y axis is 372.38570000000004
# Length of Y axis is 372.8863
# Length of Y axis is 373.237
# Length of Y axis is 373.7604
# Length of Y axis is 374.1911
# Length of Y axis is 374.6967
# Length of Y axis is 375.15100000000007
# Length of Y axis is 375.602
# Length of Y axis is 376.0699
# Length of Y axis is 376.4184
# Length of Y axis is 377.00899999999996
# Length of Y axis is 377.54269999999997
# Length of Y axis is 377.8934
# Length of Y axis is 378.49620000000004
# Length of Y axis is 378.8025
# Length of Y axis is 379.2657
# Length of Y axis is 379.902
# Length of Y axis is 380.1854
# Length of Y axis is 380.67670000000004
# Length of Y axis is 381.1464
# Length of Y axis is 381.5686
# Length of Y axis is 382.06280000000004
# Length of Y axis is 382.4542
# Length of Y axis is 382.9474
# Length of Y axis is 383.5231
# Negative stress, end of calculation 1 !
# Run 1 finished!!!!!!!!!!!!!!!!!!!

# %%
# print(len(v_s15_1))
# print(len(v_s15_2))
# print(len(v_s15_3))
# print(len(v_s15_4))
# print(len(v_s15_5))

#print(len(allStress_eq20))

# %%
totalBoxSize = 210 * 500 * 200

modelSize1 = allCoord_eq20[0][0][0] * allCoord_eq20[0][1][0] * allCoord_eq20[0][2][0]
#modelSize2 = allCoord_eq20[1][0][0] * allCoord_eq20[1][1][0] * allCoord_eq20[1][2][0]
#modelSize3 = allCoord_eq20[2][0][0] * allCoord_eq20[2][1][0] * allCoord_eq20[2][2][0]
#modelSize4 = allCoord_eq20[3][0][0] * allCoord_eq20[3][1][0] * allCoord_eq20[3][2][0]
#modelSize5 = allCoord_eq20[4][0][0] * allCoord_eq20[4][1][0] * allCoord_eq20[4][2][0]

initialLength1 = allCoord_eq20[0][1][0]
#initialLength2 = allCoord_eq20[1][1][0]
#initialLength3 = allCoord_eq20[2][1][0]
#initialLength4 = allCoord_eq20[3][1][0]
#initialLength5 = allCoord_eq20[4][1][0]


stress1 = [i * totalBoxSize / modelSize1 for i in allStress_eq20[0]]
#stress2 = [i * totalBoxSize / modelSize2 for i in allStress_eq20[1]]
#stress3 = [i * totalBoxSize / modelSize3 for i in allStress_eq20[2]]
#stress4 = [i * totalBoxSize / modelSize4 for i in allStress_eq20[3]]
#stress5 = [i * totalBoxSize / modelSize5 for i in allStress_eq20[4]]
strain1 = [(i - initialLength1)/initialLength1 for i in allCoord_eq20[0][1]]
#strain2 = [(i - initialLength2)/initialLength2 for i in allCoord_eq20[1][1]]
#strain3 = [(i - initialLength3)/initialLength3 for i in allCoord_eq20[2][1]]
#strain4 = [(i - initialLength4)/initialLength4 for i in allCoord_eq20[3][1]]
#strain5 = [(i - initialLength5)/initialLength5 for i in allCoord_eq20[4][1]]

# %%
filepathout = 'C:/Users/Berry/Documents/SS_curve_冠廷/'

run = 1
#stressStrain = [[strain1, stress1], [strain2, stress2], [strain3, stress3], [strain4, stress4], [strain5, stress5]]
stressStrain = [[strain1, stress1]]
for runs in stressStrain:
    wb = Workbook()
    ws = wb.active
    for s in range(len(runs[0])):
        ws.append([runs[0][s], runs[1][s]])
    wb.save(filepathout + fout + str(run) + '.xlsx')
    run += 1

# %%
plt.figure(dpi = 900)
plt.title('Stress-Strain (%s)' % (fout[:-1]) )
plt.plot(strain1, stress1, label = "rnd = 1")
#plt.plot(strain2, stress2, label = "rnd = 2")
#plt.plot(strain3, stress3, label = "rnd = 3")
#plt.plot(strain4, stress4, label = "rnd = 4")
#plt.plot(strain5, stress5, label = "rnd = 5")
plt.legend(loc = 'best')
plt.xlabel('strain')
plt.ylabel('stress')
plt.grid()
plt.savefig(filepathout + str(fout[:-1]) + '.png')
plt.show()

# %%
#Strain_avg = np.mean([   strain1[-1] ,strain2[-1],strain3[-1],strain4[-1],strain5[-1]   ])
#Strain_std = np.std([   strain1[-1] ,strain2[-1],strain3[-1],strain4[-1] ,strain5[-1]   ])
#Stress_avg = np.mean([   max(stress1),max(stress2),max(stress3) ,max(stress4) ,max(stress5)   ])
#Stress_std = np.std([   max(stress1),max(stress2),max(stress3) ,max(stress4) ,max(stress5)   ])

print('Strain:',strain1[-1])
print('Stress:',max(stress1))
# Out:
# Strain: 0.9176634415860396
# Stress: 4.571256654648768

# %%
# if np.nan in xarr:
#     print("Ya")

# print(math.isnan(df['x'][0]))
# print(np.isin(xarr[0], xarr).any())
# print(xarr)
# print(type(xarr[0]))

# %%
# test = df['x'][0]
# np.isnan(test)

# %%
# mainlist = []
# for i in range(1,6):
#     a = 'v_s15__'
#     b = str(i)
#     c = a+b
#     print(c)
#     c = []
#     for j in range (10):
#         c.append(j)
#     mainlist.append((c))
    
# print(mainlist)
# print(mainlist[0])

# %%
# v_s15_1 = []
# v_s15_2 = []
# v_s15_3 = []
# v_s15_4 = []
# v_s15_5 = []
# #length1 = []
# #length2 = []
# #length3 = []
# #length4 = []
# #length5 = []
# count = 1

# for filename in final_files1:
#     #df1 = pd.read_csv(filename, skiprows = 6, nrows = 1, header = None, engine='python')
#     #print(df1)
#     #st1 = [(float)(df1[0][0].split(' ')[0]), (float)(df1[0][0].split(' ')[1])]
#     #length1.append(st1[1] - st1[0])
#     df11 = pd.read_csv(filename, skiprows=8, sep=" ", engine='python')
#     #print(df)
#     df11 = df11.dropna(axis=1)
#     try:
#         df11.columns = ['ATOMS id', 'type', 'x', 'y', 'z', 'v_s4', 'v_s5', 'v_s6','v_s14', 'v_s15', 'v_s16']
#     except:
#         print('Error.')
#         print("There is nan in " + str(filename))
#         break
#     s_df11 = df11.astype(str)
#     if sum(df11['v_s15'])<-0.001 and count > 10:
#         print("Negative stress, end of calculation 1.")
#         break
#     #elif s_df11["v_s15"].str.contains("nan").any() or s_df11["v_s15"].str.contains("-nan").any():
#     elif any("nan" in s15 for s15 in s_df11['v_s15']):
#         print("Nan exists in file " + str(filename))
#         break
#     else:
#         ans1 = sum(df11['v_s15'])
#         print(ans1)
#         v_s15_1.append(ans1)
#     count += 1
        
# print("First Done!")
# count = 1

# for filename in final_files2:
#     #df2 = pd.read_csv(filename, skiprows = 6, nrows = 1, header = None, engine='python')
#     #print(df2)
#     #st2 = [(float)(df2[0][0].split(' ')[0]), (float)(df2[0][0].split(' ')[1])]
#     #length2.append(st2[1] - st2[0])
#     df22 = pd.read_csv(filename, skiprows=8, sep=" ", engine='python')
#     #print(df)
#     df22 = df22.dropna(axis=1)
#     try:
#         df22.columns = ['ATOMS id', 'type', 'x', 'y', 'z', 'v_s4', 'v_s5', 'v_s6','v_s14', 'v_s15', 'v_s16']
#     except:
#         print('Error.')
#         print("There is nan in " + str(filename))
#         break
#     s_df22 = df22.astype(str)
#     if sum(df22['v_s15'])<-0.001 and count > 10:
#         print("Negative stress, end of calculation 2.")
#         break
#     #elif s_df22["v_s15"].str.contains("nan").any() or s_df22["v_s15"].str.contains("-nan").any():
#     elif any("nan" in s15 for s15 in s_df22['v_s15']):
#         print("Nan exists in file " + str(filename))
#         break
#     else:
#         ans2 = sum(df22['v_s15'])
#         print(ans2)
#         v_s15_2.append(ans2)
#     count += 1
        
# print("Second Done!")
# count = 1

# for filename in final_files3:
#     #df3 = pd.read_csv(filename, skiprows = 6, nrows = 1, header = None, engine='python')
#     #print(df3)
#     #st3 = [(float)(df3[0][0].split(' ')[0]), (float)(df3[0][0].split(' ')[1])]
#     #length3.append(st3[1] - st3[0])
#     df33 = pd.read_csv(filename, skiprows=8, sep=" ", engine='python')
#     #print(df)
#     df33 = df33.dropna(axis=1)
#     try:
#         df33.columns = ['ATOMS id', 'type', 'x', 'y', 'z', 'v_s4', 'v_s5', 'v_s6','v_s14', 'v_s15', 'v_s16']
#     except:
#         print('Error.')
#         print("There is nan in " + str(filename))
#         break
#     s_df33 = df33.astype(str)
#     if sum(df33['v_s15'])<-0.001 and count > 10:
#         print("Negative stress, end of calculation 3.")
#         break
#     #elif s_df33["v_s15"].str.contains("nan").any() or s_df33["v_s15"].str.contains("-nan").any():
#     elif any("nan" in s15 for s15 in s_df33['v_s15']):
#         print("Nan exists in file " + str(filename))
#         break
#     else:
#         ans3 = sum(df33['v_s15'])
#         print(ans3)
#         v_s15_3.append(ans3)
#     count += 1
        
# print("Third Done!")
# count = 1

# for filename in final_files4:
#     #df4 = pd.read_csv(filename, skiprows = 6, nrows = 1, header = None, engine='python')
#     #print(df4)
#     #st4 = [(float)(df4[0][0].split(' ')[0]), (float)(df4[0][0].split(' ')[1])]
#     #length4.append(st4[1] - st4[0])
#     df44 = pd.read_csv(filename, skiprows=8, sep=" ", engine='python')
#     #print(df)
#     df44 = df44.dropna(axis=1)
#     try:
#         df44.columns = ['ATOMS id', 'type', 'x', 'y', 'z', 'v_s4', 'v_s5', 'v_s6','v_s14', 'v_s15', 'v_s16']
#     except:
#         print('Error.')
#         print("There is nan in " + str(filename))
#         break
#     s_df44 = df44.astype(str)
#     if sum(df44['v_s15'])<-0.001 and count > 10:
#         print("Negative stress, end of calculation 4.")
#         break
#     #elif s_df44["v_s15"].str.contains("nan").any() or s_df4["v_s15"].str.contains("-nan").any():
#     elif any("nan" in s15 for s15 in s_df44['v_s15']):
#         print("Nan exists in file " + str(filename))
#         break
#     else:
#         ans4 = sum(df44['v_s15'])
#         print(ans4)
#         v_s15_4.append(ans4)
#     count += 1
    
# print("Fourth Done!")
# count = 1

# for filename in final_files5:
#     #df5 = pd.read_csv(filename, skiprows = 6, nrows = 1, header = None, engine='python')
#     #print(df2)
#     #st5 = [(float)(df5[0][0].split(' ')[0]), (float)(df5[0][0].split(' ')[1])]
#     #length5.append(st5[1] - st5[0])
#     df55 = pd.read_csv(filename, skiprows=8, sep=" ", engine='python')
#     #print(df)
#     df55 = df55.dropna(axis=1)
#     try:
#         df55.columns = ['ATOMS id', 'type', 'x', 'y', 'z', 'v_s4', 'v_s5', 'v_s6','v_s14', 'v_s15', 'v_s16']
#     except:
#         print('Error.')
#         print("There is nan in " + str(filename))
#         break
#     s_df55 = df55.astype(str)
#     if any("nan" in s15 for s15 in s_df55['v_s15']):
#         print("Nan exists in file " + str(filename))
#         break
#     elif sum(df55['v_s15'])<-0.001 and count > 10:
#         print("Negative stress, end of calculation 5.")
#         break
#     #elif s_df55["v_s15"].str.contains("nan").any() or s_df55["v_s15"].str.contains("-nan").any():
#     else:
#         ans5 = sum(df55['v_s15'])
#         print(ans5)
#         v_s15_5.append(ans5)
#     count += 1
        
# print("Fifth Done!")

# %%
# xSize1 = []
# ySize1 = []
# zSize1 = []

# xSize2 = []
# ySize2 = []
# zSize2 = []

# xSize3 = []
# ySize3 = []
# zSize3 = []

# xSize4 = []
# ySize4 = []
# zSize4 = []

# xSize5 = []
# ySize5 = []
# zSize5 = []

# # strain1 = []
# # strain2 = []
# # strain3 = []
# # strain4 = []
# # strain5 = []

# count = 1

# ###  1
# for filename in final_files1:
#     df11 = pd.read_csv(filename, skiprows=8, sep=" ", engine='python')
#     #print(df11)
#     df11 = df11.dropna(axis=1)
#     #print(df11.head())
#     try:
#         df11.columns = ['ATOMS id', 'type', 'x', 'y', 'z', 'v_s4', 'v_s5', 'v_s6','v_s14', 'v_s15', 'v_s16']
#     except:
#         print('Error.')
#         print("There is nan in " + str(filename))
#         break
#     #s_df11 = df11.astype(str)
#     #if pd.isnull(df11['v_s15']).any():
#     #any("nan" in s15 for s15 in s_df11['v_s15']):
#     arr1 = df11['x'].values
#     if math.isnan(df11['x'][0]):
#     #if np.isin(arr1, np.nan).any():
#         print("There is nan in " + str(filename))
#         break        
#     elif sum(df11['v_s15'])<-0.001 and count > 10:
#         print("Negative stress in run 1")
#         break
#     else:
# #         xMin = min(df11['x'])
# #         xMax = max(df11['x'])
# #         yMin = min(df11['y'])
# #         yMax = max(df11['y'])
# #         zMin = min(df11['z'])
# #         zMax = max(df11['z'])
#         xLen = max(df11['x']) - min(df11['x'])
#         yLen = max(df11['y']) - min(df11['y'])
#         zLen = max(df11['z']) - min(df11['z'])
#         xSize1.append(xLen)
#         ySize1.append(yLen)
#         zSize1.append(zLen)
#         print("Length of Y axis is " + str(yLen))
#     #print("Length of x is %.3f" %xLen)
#     #print("Length of y is %.3f" %yLen)
#     #print("Length of z is %.3f" %zLen)
#     count += 1
# print("Run 1 finished!")
# count = 1    
    
# ###  2    
# for filename in final_files2:
#     df22 = pd.read_csv(filename, skiprows=8, sep=" ", engine='python')
#     #print(df)
#     df22 = df22.dropna(axis=1)
#     #print(df)
#     try:
#         df22.columns = ['ATOMS id', 'type', 'x', 'y', 'z', 'v_s4', 'v_s5', 'v_s6','v_s14', 'v_s15', 'v_s16']
#     except:
#         print('Error.')
#         print("There is nan in " + str(filename))
#         break
        
#     #s_df22 = df22.astype(str)
#     arr2 = df22['x'].values
#     #if np.isin(arr2, np.nan).any():
    
#     if math.isnan(df22['x'][0]):
#         print("There is nan in " + str(filename))
#         break
#     elif np.sum(df22['v_s15'].values)<-0.001 and count > 10:
#         print("Negative stress in run 2")
#         break
#     else:
#         xLen = np.max(df22['x'].values) - np.min(df22['x'].values)
#         yLen = np.max(df22['y'].values) - np.min(df22['y'].values)
#         zLen = np.max(df22['z'].values) - np.min(df22['z'].values)
#         xSize2.append(xLen)
#         ySize2.append(yLen)
#         zSize2.append(zLen)
#         print("Length of Y axis is " + str(yLen))
# print("Run 2 finished!")
# count = 1

# ###  3  
# for filename in final_files3:
#     df33 = pd.read_csv(filename, skiprows=8, sep=" ", engine='python')
#     #print(df)
#     df33 = df33.dropna(axis=1)
#     try:
#         df33.columns = ['ATOMS id', 'type', 'x', 'y', 'z', 'v_s4', 'v_s5', 'v_s6','v_s14', 'v_s15', 'v_s16']
#     except:
#         print('Error.')
#         print("There is nan in " + str(filename))
#         break
#     arr3 = df33['x'].values
#     #if np.isin(arr3, np.nan).any():
#     if math.isnan(df33['x'][0]):
#         print("There is nan in " + str(filename))
#         break
#     elif sum(df33['v_s15'])<-0.001 and count > 10:
#         print("Negative stress in run 3")
#         break
#     else:
#         xLen = max(df33['x']) - min(df33['x'])
#         yLen = max(df33['y']) - min(df33['y'])
#         zLen = max(df33['z']) - min(df33['z'])
#         xSize3.append(xLen)
#         ySize3.append(yLen)
#         zSize3.append(zLen)
#         print("Length of Y axis is " + str(yLen))
# print("Run 3 finished!")
# count = 1

# ###  4
# for filename in final_files2:
#     df44 = pd.read_csv(filename, skiprows=8, sep=" ", engine='python')
#     #print(df)
#     df44 = df44.dropna(axis=1)
#     try:
#         df44.columns = ['ATOMS id', 'type', 'x', 'y', 'z', 'v_s4', 'v_s5', 'v_s6','v_s14', 'v_s15', 'v_s16']
#     except:
#         print('Error.')
#         print("There is nan in " + str(filename))
#         break
#     arr4 = df44['x'].values
#     #if np.isin(arr4, np.nan).any():
#     if math.isnan(df44['x'][0]):
#         print("There is nan in " + str(filename))
#         break
#     elif sum(df44['v_s15'])<-0.001 and count > 10:
#         print("Negative stress in run 4")
#         break
#     else:
#         xLen = max(df44['x']) - min(df44['x'])
#         yLen = max(df44['y']) - min(df44['y'])
#         zLen = max(df44['z']) - min(df44['z'])
#         xSize4.append(xLen)
#         ySize4.append(yLen)
#         zSize4.append(zLen)
#         print("Length of Y axis is " + str(yLen))
# print("Run 4 finished!")
# count = 1

# ###  5
# for filename in final_files5:
#     df55 = pd.read_csv(filename, skiprows=8, sep=" ", engine='python')
#     #print(df)
#     df55 = df55.dropna(axis=1)
#     try:
#         df55.columns = ['ATOMS id', 'type', 'x', 'y', 'z', 'v_s4', 'v_s5', 'v_s6','v_s14', 'v_s15', 'v_s16']
#     except:
#         print('Error.')
#         print("There is nan in " + str(filename))
#         break
#     arr5 = df55['x'].values
#     #if np.isin(arr5, np.nan).any():
#     if math.isnan(df55['x'][0]):
#         print("There is nan in " + str(filename))
#         break
#     elif sum(df55['v_s15'])<-0.001 and count > 10:
#         print("Negative stress in run 5")
#         break
#     else:
#         xLen = max(df55['x']) - min(df55['x'])
#         yLen = max(df55['y']) - min(df55['y'])
#         zLen = max(df55['z']) - min(df55['z'])
#         xSize5.append(xLen)
#         ySize5.append(yLen)
#         zSize5.append(zLen)
#         print("Length of Y axis is " + str(yLen))
# print("Run 5 finished!")
