# %%
import pandas as pd
import numpy as np
import glob
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
from openpyxl import Workbook
#from scipy.interpolate import interpld
from scipy.interpolate import spline
import math

# %%
fout = 'BO1_C06_'
filepath1 = 'H:/HEA/Finished/C06_BO1_2345674'
#filepath2 = 'H:/HEA/Finished/C01_BO1_2345675'
#filepath3 = 'H:/HEA/Finished/C01_BO1_2345676'
#filepath4 = 'H:/HEA/Finished/C01_BO1_2345677'
#filepath5 = 'H:/HEA/Finished/C01_BO1_2345678'
# filepath1 = 'C:/Users/Tim.Jason-PC/Desktop/HEY/研究交接資料/fraction_of_Mn/Co23Ni23Cr23Fe23Mn8_110_modify/1_1500K/'
# filepath2 = 'C:/Users/Tim.Jason-PC/Desktop/HEY/研究交接資料/Fe/Fe0/20150901_100800/2_tension_1e-3_300K_sss_fracture_4/'
# filepath3 = 'C:/Users/Tim.Jason-PC/Desktop/HEY/研究交接資料/fraction_of_Mn/co25ni25cr25fe25_110_modify/20150901_100800/2_tension_1e-3_300K_sss_fracture_4/'
# filepath4 = 'C:/Users/Tim.Jason-PC/Desktop/HEY/研究交接資料/fraction_of_Mn/Co23Ni23Cr23Fe23Mn8_110_modify/1_1500K/'
# filepath5 = 'C:/Users/Tim.Jason-PC/Desktop/HEY/研究交接資料/Fe/Fe0/20150901_100800/2_tension_1e-3_300K_sss_fracture_4/'
#filepath = 'D:/tensile_md/test/real_final3/normal/'

all_files1 = glob.glob(filepath1 + '/dump/eq20_uniaxial.mid_convert.*')
#all_files2 = glob.glob(filepath2 + '/dump/eq20_uniaxial.mid_convert.*')
#all_files3 = glob.glob(filepath3 + '/dump/eq20_uniaxial.mid_convert.*')
#all_files4 = glob.glob(filepath4 + '/dump/eq20_uniaxial.mid_convert.*')
#all_files5 = glob.glob(filepath5 + '/dump/eq20_uniaxial.mid_convert.*')

files_number1 = [[file, (int)(file.split('.')[-1])] for file in all_files1]
#files_number2 = [[file, (int)(file.split('.')[-1])] for file in all_files2]
#files_number3 = [[file, (int)(file.split('.')[-1])] for file in all_files3]
#files_number4 = [[file, (int)(file.split('.')[-1])] for file in all_files4]
#files_number5 = [[file, (int)(file.split('.')[-1])] for file in all_files5]

sort_files1 = sorted(files_number1, key=lambda x: x[1])
#sort_files2 = sorted(files_number2, key=lambda x: x[1])
#sort_files3 = sorted(files_number3, key=lambda x: x[1])
#sort_files4 = sorted(files_number4, key=lambda x: x[1])
#sort_files5 = sorted(files_number5, key=lambda x: x[1])

final_files1 = [x[0] for x in sort_files1]
#final_files2 = [x[0] for x in sort_files2]
#final_files3 = [x[0] for x in sort_files3]
#final_files4 = [x[0] for x in sort_files4]
#final_files5 = [x[0] for x in sort_files5]
print(final_files1)
#print(final_files2)
#print(final_files3)
#print(final_files4)
#print(final_files5)


#print(all_files[1])
#print(files_number[1])
#print(sort_files[1])
#print(final_files1)
#print(final_files2)
#print(final_files3)
# Out:
# ['H:/HEA/Finished/C06_BO1_2345674/dump\\eq20_uniaxial.mid_convert.0', 'H:/HEA/Finished/C06_BO1_2345674/dump\\eq20_uniaxial.mid_convert.1000', 'H:/HEA/Finished/C06_BO1_2345674/dump\\eq20_uniaxial.mid_convert.2000', 'H:/HEA/Finished/C06_BO1_2345674/dump\\eq20_uniaxial.mid_convert.3000', 'H:/HEA/Finished/C06_BO1_2345674/dump\\eq20_uniaxial.mid_convert.4000', 'H:/HEA/Finished/C06_BO1_2345674/dump\\eq20_uniaxial.mid_convert.5000', 'H:/HEA/Finished/C06_BO1_2345674/dump\\eq20_uniaxial.mid_convert.6000', 'H:/HEA/Finished/C06_BO1_2345674/dump\\eq20_uniaxial.mid_convert.7000', 'H:/HEA/Finished/C06_BO1_2345674/dump\\eq20_uniaxial.mid_convert.8000', 'H:/HEA/Finished/C06_BO1_2345674/dump\\eq20_uniaxial.mid_convert.9000', 'H:/HEA/Finished/C06_BO1_2345674/dump\\eq20_uniaxial.mid_convert.10000', 'H:/HEA/Finished/C06_BO1_2345674/dump\\eq20_uniaxial.mid_convert.11000', 'H:/HEA/Finished/C06_BO1_2345674/dump\\eq20_uniaxial.mid_convert.12000', 'H:/HEA/Finished/C06_BO1_2345674/dump\\eq20_uniaxial.mid_convert.13000', 'H:/HEA/Finished/C06_BO1_2345674/dump\\eq20_uniaxial.mid_convert.14000', 'H:/HEA/Finished/C06_BO1_2345674/dump\\eq20_uniaxial.mid_convert.15000', 'H:/HEA/Finished/C06_BO1_2345674/dump\\eq20_uniaxial.mid_convert.16000', 'H:/HEA/Finished/C06_BO1_2345674/dump\\eq20_uniaxial.mid_convert.17000', 'H:/HEA/Finished/C06_BO1_2345674/dump\\eq20_uniaxial.mid_convert.18000', 'H:/HEA/Finished/C06_BO1_2345674/dump\\eq20_uniaxial.mid_convert.19000', 'H:/HEA/Finished/C06_BO1_2345674/dump\\eq20_uniaxial.mid_convert.20000', 'H:/HEA/Finished/C06_BO1_2345674/dump\\eq20_uniaxial.mid_convert.21000', 'H:/HEA/Finished/C06_BO1_2345674/dump\\eq20_uniaxial.mid_convert.22000', 'H:/HEA/Finished/C06_BO1_2345674/dump\\eq20_uniaxial.mid_convert.23000', 'H:/HEA/Finished/C06_BO1_2345674/dump\\eq20_uniaxial.mid_convert.24000', 'H:/HEA/Finished/C06_BO1_2345674/dump\\eq20_uniaxial.mid_convert.25000', 'H:/HEA/Finished/C06_BO1_2345674/dump\\eq20_uniaxial.mid_convert.26000', 'H:/HEA/Finished/C06_BO1_2345674/dump\\eq20_uniaxial.mid_convert.27000', 'H:/HEA/Finished/C06_BO1_2345674/dump\\eq20_uniaxial.mid_convert.28000', 'H:/HEA/Finished/C06_BO1_2345674/dump\\eq20_uniaxial.mid_convert.29000', 'H:/HEA/Finished/C06_BO1_2345674/dump\\eq20_uniaxial.mid_convert.30000', 'H:/HEA/Finished/C06_BO1_2345674/dump\\eq20_uniaxial.mid_convert.31000', 'H:/HEA/Finished/C06_BO1_2345674/dump\\eq20_uniaxial.mid_convert.32000', 'H:/HEA/Finished/C06_BO1_2345674/dump\\eq20_uniaxial.mid_convert.33000', 'H:/HEA/Finished/C06_BO1_2345674/dump\\eq20_uniaxial.mid_convert.34000', 'H:/HEA/Finished/C06_BO1_2345674/dump\\eq20_uniaxial.mid_convert.35000', 'H:/HEA/Finished/C06_BO1_2345674/dump\\eq20_uniaxial.mid_convert.36000', 'H:/HEA/Finished/C06_BO1_2345674/dump\\eq20_uniaxial.mid_convert.37000', 'H:/HEA/Finished/C06_BO1_2345674/dump\\eq20_uniaxial.mid_convert.38000', 'H:/HEA/Finished/C06_BO1_2345674/dump\\eq20_uniaxial.mid_convert.39000', 'H:/HEA/Finished/C06_BO1_2345674/dump\\eq20_uniaxial.mid_convert.40000', 'H:/HEA/Finished/C06_BO1_2345674/dump\\eq20_uniaxial.mid_convert.41000', 'H:/HEA/Finished/C06_BO1_2345674/dump\\eq20_uniaxial.mid_convert.42000', 'H:/HEA/Finished/C06_BO1_2345674/dump\\eq20_uniaxial.mid_convert.43000', 'H:/HEA/Finished/C06_BO1_2345674/dump\\eq20_uniaxial.mid_convert.44000', 'H:/HEA/Finished/C06_BO1_2345674/dump\\eq20_uniaxial.mid_convert.45000', 'H:/HEA/Finished/C06_BO1_2345674/dump\\eq20_uniaxial.mid_convert.46000', 'H:/HEA/Finished/C06_BO1_2345674/dump\\eq20_uniaxial.mid_convert.47000', 'H:/HEA/Finished/C06_BO1_2345674/dump\\eq20_uniaxial.mid_convert.48000', 'H:/HEA/Finished/C06_BO1_2345674/dump\\eq20_uniaxial.mid_convert.49000', 'H:/HEA/Finished/C06_BO1_2345674/dump\\eq20_uniaxial.mid_convert.50000', 'H:/HEA/Finished/C06_BO1_2345674/dump\\eq20_uniaxial.mid_convert.51000', 'H:/HEA/Finished/C06_BO1_2345674/dump\\eq20_uniaxial.mid_convert.52000', 'H:/HEA/Finished/C06_BO1_2345674/dump\\eq20_uniaxial.mid_convert.53000', 'H:/HEA/Finished/C06_BO1_2345674/dump\\eq20_uniaxial.mid_convert.54000 ...

# %%
#loadedFiles = [final_files1, final_files2, final_files3, final_files4, final_files5]
loadedFiles = [final_files1]
print(loadedFiles)
# Out:
# [['H:/HEA/Finished/C06_BO1_2345674/dump\\eq20_uniaxial.mid_convert.0', 'H:/HEA/Finished/C06_BO1_2345674/dump\\eq20_uniaxial.mid_convert.1000', 'H:/HEA/Finished/C06_BO1_2345674/dump\\eq20_uniaxial.mid_convert.2000', 'H:/HEA/Finished/C06_BO1_2345674/dump\\eq20_uniaxial.mid_convert.3000', 'H:/HEA/Finished/C06_BO1_2345674/dump\\eq20_uniaxial.mid_convert.4000', 'H:/HEA/Finished/C06_BO1_2345674/dump\\eq20_uniaxial.mid_convert.5000', 'H:/HEA/Finished/C06_BO1_2345674/dump\\eq20_uniaxial.mid_convert.6000', 'H:/HEA/Finished/C06_BO1_2345674/dump\\eq20_uniaxial.mid_convert.7000', 'H:/HEA/Finished/C06_BO1_2345674/dump\\eq20_uniaxial.mid_convert.8000', 'H:/HEA/Finished/C06_BO1_2345674/dump\\eq20_uniaxial.mid_convert.9000', 'H:/HEA/Finished/C06_BO1_2345674/dump\\eq20_uniaxial.mid_convert.10000', 'H:/HEA/Finished/C06_BO1_2345674/dump\\eq20_uniaxial.mid_convert.11000', 'H:/HEA/Finished/C06_BO1_2345674/dump\\eq20_uniaxial.mid_convert.12000', 'H:/HEA/Finished/C06_BO1_2345674/dump\\eq20_uniaxial.mid_convert.13000', 'H:/HEA/Finished/C06_BO1_2345674/dump\\eq20_uniaxial.mid_convert.14000', 'H:/HEA/Finished/C06_BO1_2345674/dump\\eq20_uniaxial.mid_convert.15000', 'H:/HEA/Finished/C06_BO1_2345674/dump\\eq20_uniaxial.mid_convert.16000', 'H:/HEA/Finished/C06_BO1_2345674/dump\\eq20_uniaxial.mid_convert.17000', 'H:/HEA/Finished/C06_BO1_2345674/dump\\eq20_uniaxial.mid_convert.18000', 'H:/HEA/Finished/C06_BO1_2345674/dump\\eq20_uniaxial.mid_convert.19000', 'H:/HEA/Finished/C06_BO1_2345674/dump\\eq20_uniaxial.mid_convert.20000', 'H:/HEA/Finished/C06_BO1_2345674/dump\\eq20_uniaxial.mid_convert.21000', 'H:/HEA/Finished/C06_BO1_2345674/dump\\eq20_uniaxial.mid_convert.22000', 'H:/HEA/Finished/C06_BO1_2345674/dump\\eq20_uniaxial.mid_convert.23000', 'H:/HEA/Finished/C06_BO1_2345674/dump\\eq20_uniaxial.mid_convert.24000', 'H:/HEA/Finished/C06_BO1_2345674/dump\\eq20_uniaxial.mid_convert.25000', 'H:/HEA/Finished/C06_BO1_2345674/dump\\eq20_uniaxial.mid_convert.26000', 'H:/HEA/Finished/C06_BO1_2345674/dump\\eq20_uniaxial.mid_convert.27000', 'H:/HEA/Finished/C06_BO1_2345674/dump\\eq20_uniaxial.mid_convert.28000', 'H:/HEA/Finished/C06_BO1_2345674/dump\\eq20_uniaxial.mid_convert.29000', 'H:/HEA/Finished/C06_BO1_2345674/dump\\eq20_uniaxial.mid_convert.30000', 'H:/HEA/Finished/C06_BO1_2345674/dump\\eq20_uniaxial.mid_convert.31000', 'H:/HEA/Finished/C06_BO1_2345674/dump\\eq20_uniaxial.mid_convert.32000', 'H:/HEA/Finished/C06_BO1_2345674/dump\\eq20_uniaxial.mid_convert.33000', 'H:/HEA/Finished/C06_BO1_2345674/dump\\eq20_uniaxial.mid_convert.34000', 'H:/HEA/Finished/C06_BO1_2345674/dump\\eq20_uniaxial.mid_convert.35000', 'H:/HEA/Finished/C06_BO1_2345674/dump\\eq20_uniaxial.mid_convert.36000', 'H:/HEA/Finished/C06_BO1_2345674/dump\\eq20_uniaxial.mid_convert.37000', 'H:/HEA/Finished/C06_BO1_2345674/dump\\eq20_uniaxial.mid_convert.38000', 'H:/HEA/Finished/C06_BO1_2345674/dump\\eq20_uniaxial.mid_convert.39000', 'H:/HEA/Finished/C06_BO1_2345674/dump\\eq20_uniaxial.mid_convert.40000', 'H:/HEA/Finished/C06_BO1_2345674/dump\\eq20_uniaxial.mid_convert.41000', 'H:/HEA/Finished/C06_BO1_2345674/dump\\eq20_uniaxial.mid_convert.42000', 'H:/HEA/Finished/C06_BO1_2345674/dump\\eq20_uniaxial.mid_convert.43000', 'H:/HEA/Finished/C06_BO1_2345674/dump\\eq20_uniaxial.mid_convert.44000', 'H:/HEA/Finished/C06_BO1_2345674/dump\\eq20_uniaxial.mid_convert.45000', 'H:/HEA/Finished/C06_BO1_2345674/dump\\eq20_uniaxial.mid_convert.46000', 'H:/HEA/Finished/C06_BO1_2345674/dump\\eq20_uniaxial.mid_convert.47000', 'H:/HEA/Finished/C06_BO1_2345674/dump\\eq20_uniaxial.mid_convert.48000', 'H:/HEA/Finished/C06_BO1_2345674/dump\\eq20_uniaxial.mid_convert.49000', 'H:/HEA/Finished/C06_BO1_2345674/dump\\eq20_uniaxial.mid_convert.50000', 'H:/HEA/Finished/C06_BO1_2345674/dump\\eq20_uniaxial.mid_convert.51000', 'H:/HEA/Finished/C06_BO1_2345674/dump\\eq20_uniaxial.mid_convert.52000', 'H:/HEA/Finished/C06_BO1_2345674/dump\\eq20_uniaxial.mid_convert.53000', 'H:/HEA/Finished/C06_BO1_2345674/dump\\eq20_uniaxial.mid_convert.5400 ...

# %%
allStress_eq20 = []

count = 1
run = 1

for finalFiles in loadedFiles:
    listName = 'v_s15__' + str(run)
    listName = []
    
    for file in finalFiles:
        df = pd.read_csv(file, skiprows=8, sep=" ", engine='python')
        df = df.dropna(axis=1)
        try:
            df.columns = ['ATOMS id', 'type', 'x', 'y', 'z', 'v_s4', 'v_s5', 'v_s6','v_s14', 'v_s15', 'v_s16']
        except:
            print('Error.')
            print("There is nan in " + str(file))
            break
        s_df = df.astype(str)
        if sum(df['v_s15'])<-0.001 and count > 10:
            print("Negative stress, end of calculation " + str(run) + " !")
            break
        #elif s_df11["v_s15"].str.contains("nan").any() or s_df11["v_s15"].str.contains("-nan").any():
        elif any("nan" in s15 for s15 in s_df['v_s15']):
            print("Nan exists in file " + str(file))
            break
        else:
            ans = sum(df['v_s15'])
            print(ans)
            listName.append(ans)
        count += 1
    allStress_eq20.append(listName)
    print("Run " + str(run) + " finished!!!!!!!!!!!!!!!!!!!")
    count = 1
    run += 1
# Out:
# 0.0006256795096618378
# 0.033924198913263086
# 0.03324888230858382
# 0.06249521517066767
# 0.08126652235778181
# 0.10397561678699883
# 0.12909695320082784
# 0.15548901808850266
# 0.18380760535009313
# 0.20923007470022384
# 0.23563184072198445
# 0.2496866919379689
# 0.26061549399181333
# 0.2469655154340957
# 0.23933088959719112
# 0.2308346922956097
# 0.22068401957265674
# 0.21084229890402556
# 0.1996692052537314
# 0.19694055817507727
# 0.18868353493399762
# 0.18827593249064126
# 0.18581739030648092
# 0.18699326289649054
# 0.18934267323951712
# 0.1882482716883165
# 0.19343350058649586
# 0.19529993365500342
# 0.20474690667505469
# 0.21069520329834937
# 0.21719881295212415
# 0.2108322590917932
# 0.21843935149304913
# 0.2186993488566085
# 0.2263030138921876
# 0.22528092539602773
# 0.2248971680439879
# 0.2242860085158925
# 0.22203697246647325
# 0.216199774928255
# 0.20904231027900377
# 0.19592225316864056
# 0.18444240759556124
# 0.17695803642919375
# 0.16655228330791877
# 0.1584180943895074
# 0.15309688052343584
# 0.14831305725579272
# 0.14726809827151252
# 0.1413839738883165
# 0.14176569325019112
# 0.13654817531914018
# 0.13502815717368943
# 0.13269074512642376
# 0.12762631835011712
# 0.12619751730364345
# 0.12287103008576804
# 0.12124816728253131
# 0.1197850170596409
# 0.1130050891103713
# 0.11206414342185154
# 0.11088867392153719
# 0.10611324557882353
# 0.10464637043382076
# 0.09908381367171872
# 0.10168761268294153
# 0.10130583642679325
# 0.09745228452016014
# 0.0946108587993273
# 0.0943569713323133
# 0.08809457399633581
# 0.08878693263268093
# 0.08711819560801545
# 0.08654478461509128
# 0.08292560729134918
# 0.08731765529987362
# 0.0835851492122609
# 0.08207823755993154
# 0.07789085009647564
# 0.07561380609223585
# 0.06957083639812683
# 0.06878335996759966
# 0.06200251794088028
# 0.060440074717147525
# 0.058661602114457555
# 0.05485277810227155
# 0.05477147836639156
# 0.054732058393191105
# 0.054619113195657584
# 0.05623356036301098
# 0.05431357725354618
# 0.05111549546149393
# 0.05525517660679556
# 0.05093168291021042
# 0.0512506618405564
# 0.047537886058048255
# 0.04498064295116114
# 0.04425032895830513
# 0.04109455635250637
# 0.04120521297587709
# 0.041917766876115106
# 0.03702820359123899
# 0.03747461492959992
# 0.035238962529381745
# 0.03589867525888421
# 0.03286542268251201
# 0.03196765770353358
# 0.02775548542548544
# 0.029440751247788912
# 0.026623550013723893
# 0.024447446537139563
# 0.02503610910177195
# 0.020137448346828124
# 0.02262643281822812
# 0.02442011354952115
# 0.02339355192286731
# 0.022580659266470907
# 0.022699815815158165
# 0.023382553708457123
# 0.020634996629387087
# 0.01653337206345866
# 0.02128564917370388
# 0.017682473324525355
# 0.016620613855355744
# 0.0189964211581281
# 0.01614692181668217
# 0.014680429760096248
# 0.01102023865633113
# 0.00892933924724401
# 0.009522480180799296
# 0.007465216726973074
# 0.00846954806196671
# 0.006433651473474989
# 0.00517339307362983
# 0.005035779052599016
# 0.007030702277288897
# 0.005339300341304873
# 0.005643535457470311
# 0.00571752923169247
# Negative stress, end of calculation 1 !
# Run 1 finished!!!!!!!!!!!!!!!!!!!

# %%
allCoord_eq20 = []

count = 1
run = 1

for finalFiles in loadedFiles:
    listX = 'xSize_' + str(run)
    listX = []
    listY = 'ySize_' + str(run)
    listY = []    
    listZ = 'zSize_' + str(run)
    listZ = []
    listCoord = 'run_' + str(run)
    listCoord = []
    
    for file in finalFiles:
        df = pd.read_csv(file, skiprows=8, sep=" ", engine='python')
        df = df.dropna(axis=1)
        try:
            df.columns = ['ATOMS id', 'type', 'x', 'y', 'z', 'v_s4', 'v_s5', 'v_s6','v_s14', 'v_s15', 'v_s16']
        except:
            print('Error.')
            print("There is nan in " + str(file))
            break
        if math.isnan(df['x'][0]):
            print("There is nan in " + str(file))
            break
        elif np.sum(df['v_s15'].values)<-0.001 and count > 10:
            print("Negative stress, end of calculation " + str(run) + " !")
            break
        else:
            xLen = np.max(df['x'].values) - np.min(df['x'].values)
            yLen = np.max(df['y'].values) - np.min(df['y'].values)
            zLen = np.max(df['z'].values) - np.min(df['z'].values)
            listX.append(xLen)
            listY.append(yLen)
            listZ.append(zLen)
            print("Length of Y axis is " + str(yLen))
        count += 1
    allCoord_eq20.append([listX, listY, listZ])
    print("Run " + str(run) + " finished!!!!!!!!!!!!!!!!!!!")
    count = 1
    run += 1
# Out:
# Length of Y axis is 199.99820000000003
# Length of Y axis is 201.59480000000002
# Length of Y axis is 202.88420000000002
# Length of Y axis is 204.3182
# Length of Y axis is 205.6373
# Length of Y axis is 206.8265
# Length of Y axis is 208.10179999999997
# Length of Y axis is 209.55270000000002
# Length of Y axis is 210.8345
# Length of Y axis is 212.18560000000002
# Length of Y axis is 213.4538
# Length of Y axis is 214.8877
# Length of Y axis is 216.22290000000004
# Length of Y axis is 217.53629999999998
# Length of Y axis is 218.8072
# Length of Y axis is 220.1987
# Length of Y axis is 221.519
# Length of Y axis is 222.6829
# Length of Y axis is 223.9131
# Length of Y axis is 225.2586
# Length of Y axis is 226.3997
# Length of Y axis is 227.5917
# Length of Y axis is 228.7059
# Length of Y axis is 229.9362
# Length of Y axis is 231.0738
# Length of Y axis is 232.2342
# Length of Y axis is 233.2619
# Length of Y axis is 234.47663999999997
# Length of Y axis is 235.53275
# Length of Y axis is 236.59249
# Length of Y axis is 237.7635
# Length of Y axis is 238.90451000000002
# Length of Y axis is 239.88231
# Length of Y axis is 240.93578
# Length of Y axis is 242.05991
# Length of Y axis is 243.06043
# Length of Y axis is 244.13015000000001
# Length of Y axis is 245.11593
# Length of Y axis is 246.13152
# Length of Y axis is 247.1547
# Length of Y axis is 248.12285000000003
# Length of Y axis is 248.98959000000002
# Length of Y axis is 250.04186
# Length of Y axis is 251.04148000000004
# Length of Y axis is 252.039465
# Length of Y axis is 252.87521900000002
# Length of Y axis is 253.8400799
# Length of Y axis is 254.860918
# Length of Y axis is 255.557251
# Length of Y axis is 256.46065999999996
# Length of Y axis is 257.34007
# Length of Y axis is 258.21332
# Length of Y axis is 259.08754
# Length of Y axis is 259.90840000000003
# Length of Y axis is 260.82447
# Length of Y axis is 261.75846
# Length of Y axis is 262.42769
# Length of Y axis is 263.37132
# Length of Y axis is 264.14907
# Length of Y axis is 265.01788999999997
# Length of Y axis is 265.78806
# Length of Y axis is 266.6351
# Length of Y axis is 267.41938
# Length of Y axis is 268.24031
# Length of Y axis is 269.12165999999996
# Length of Y axis is 269.85476
# Length of Y axis is 270.62857999999994
# Length of Y axis is 271.48625
# Length of Y axis is 272.22303
# Length of Y axis is 272.99648
# Length of Y axis is 273.76603
# Length of Y axis is 274.52689999999996
# Length of Y axis is 275.3439
# Length of Y axis is 276.0809
# Length of Y axis is 276.7754
# Length of Y axis is 277.6046
# Length of Y axis is 278.3218
# Length of Y axis is 278.9639
# Length of Y axis is 279.7783
# Length of Y axis is 280.49580000000003
# Length of Y axis is 281.2653
# Length of Y axis is 281.9585
# Length of Y axis is 282.8303
# Length of Y axis is 283.4679
# Length of Y axis is 284.22659999999996
# Length of Y axis is 284.9692
# Length of Y axis is 285.7549
# Length of Y axis is 286.3913
# Length of Y axis is 287.12850000000003
# Length of Y axis is 287.90950000000004
# Length of Y axis is 288.5254
# Length of Y axis is 289.2487
# Length of Y axis is 290.02500000000003
# Length of Y axis is 290.76919999999996
# Length of Y axis is 291.3889
# Length of Y axis is 292.15740000000005
# Length of Y axis is 292.7579
# Length of Y axis is 293.5288
# Length of Y axis is 294.1924
# Length of Y axis is 294.9646
# Length of Y axis is 295.7151
# Length of Y axis is 296.3462
# Length of Y axis is 296.9742
# Length of Y axis is 297.7027
# Length of Y axis is 298.4184
# Length of Y axis is 299.12699999999995
# Length of Y axis is 299.8458
# Length of Y axis is 300.4996
# Length of Y axis is 301.1848
# Length of Y axis is 301.88259999999997
# Length of Y axis is 302.5677
# Length of Y axis is 303.3081
# Length of Y axis is 303.89050000000003
# Length of Y axis is 304.6408
# Length of Y axis is 305.2899
# Length of Y axis is 305.9935
# Length of Y axis is 306.6643
# Length of Y axis is 307.3341
# Length of Y axis is 308.042
# Length of Y axis is 308.695
# Length of Y axis is 309.34650000000005
# Length of Y axis is 310.077
# Length of Y axis is 310.71500000000003
# Length of Y axis is 311.3662
# Length of Y axis is 312.1064
# Length of Y axis is 312.76349999999996
# Length of Y axis is 313.4079
# Length of Y axis is 314.1957
# Length of Y axis is 314.7724
# Length of Y axis is 315.4608
# Length of Y axis is 316.23040000000003
# Length of Y axis is 316.7909
# Length of Y axis is 317.4879
# Length of Y axis is 318.1821
# Length of Y axis is 318.7829
# Length of Y axis is 319.55719999999997
# Length of Y axis is 320.1882
# Length of Y axis is 320.8175
# Length of Y axis is 321.51730000000003
# Negative stress, end of calculation 1 !
# Run 1 finished!!!!!!!!!!!!!!!!!!!

# %%
# print(len(v_s15_1))
# print(len(v_s15_2))
# print(len(v_s15_3))
# print(len(v_s15_4))
# print(len(v_s15_5))

#print(len(allStress_eq20))

# %%
totalBoxSize = 210 * 500 * 200

modelSize1 = allCoord_eq20[0][0][0] * allCoord_eq20[0][1][0] * allCoord_eq20[0][2][0]
#modelSize2 = allCoord_eq20[1][0][0] * allCoord_eq20[1][1][0] * allCoord_eq20[1][2][0]
#modelSize3 = allCoord_eq20[2][0][0] * allCoord_eq20[2][1][0] * allCoord_eq20[2][2][0]
#modelSize4 = allCoord_eq20[3][0][0] * allCoord_eq20[3][1][0] * allCoord_eq20[3][2][0]
#modelSize5 = allCoord_eq20[4][0][0] * allCoord_eq20[4][1][0] * allCoord_eq20[4][2][0]

initialLength1 = allCoord_eq20[0][1][0]
#initialLength2 = allCoord_eq20[1][1][0]
#initialLength3 = allCoord_eq20[2][1][0]
#initialLength4 = allCoord_eq20[3][1][0]
#initialLength5 = allCoord_eq20[4][1][0]


stress1 = [i * totalBoxSize / modelSize1 for i in allStress_eq20[0]]
#stress2 = [i * totalBoxSize / modelSize2 for i in allStress_eq20[1]]
#stress3 = [i * totalBoxSize / modelSize3 for i in allStress_eq20[2]]
#stress4 = [i * totalBoxSize / modelSize4 for i in allStress_eq20[3]]
#stress5 = [i * totalBoxSize / modelSize5 for i in allStress_eq20[4]]
strain1 = [(i - initialLength1)/initialLength1 for i in allCoord_eq20[0][1]]
#strain2 = [(i - initialLength2)/initialLength2 for i in allCoord_eq20[1][1]]
#strain3 = [(i - initialLength3)/initialLength3 for i in allCoord_eq20[2][1]]
#strain4 = [(i - initialLength4)/initialLength4 for i in allCoord_eq20[3][1]]
#strain5 = [(i - initialLength5)/initialLength5 for i in allCoord_eq20[4][1]]

# %%
filepathout = 'C:/Users/Berry/Documents/SS_curve_冠廷/'

run = 1
#stressStrain = [[strain1, stress1], [strain2, stress2], [strain3, stress3], [strain4, stress4], [strain5, stress5]]
stressStrain = [[strain1, stress1]]
for runs in stressStrain:
    wb = Workbook()
    ws = wb.active
    for s in range(len(runs[0])):
        ws.append([runs[0][s], runs[1][s]])
    wb.save(filepathout + fout + str(run) + '.xlsx')
    run += 1

# %%
plt.figure(dpi = 900)
plt.title('Stress-Strain (%s)' % (fout[:-1]) )
plt.plot(strain1, stress1, label = "rnd = 1")
#plt.plot(strain2, stress2, label = "rnd = 2")
#plt.plot(strain3, stress3, label = "rnd = 3")
#plt.plot(strain4, stress4, label = "rnd = 4")
#plt.plot(strain5, stress5, label = "rnd = 5")
plt.legend(loc = 'best')
plt.xlabel('strain')
plt.ylabel('stress')
plt.grid()
plt.savefig(filepathout + str(fout[:-1]) + '.png')
plt.show()

# %%
#Strain_avg = np.mean([   strain1[-1] ,strain2[-1],strain3[-1],strain4[-1],strain5[-1]   ])
#Strain_std = np.std([   strain1[-1] ,strain2[-1],strain3[-1],strain4[-1] ,strain5[-1]   ])
#Stress_avg = np.mean([   max(stress1),max(stress2),max(stress3) ,max(stress4) ,max(stress5)   ])
#Stress_std = np.std([   max(stress1),max(stress2),max(stress3) ,max(stress4) ,max(stress5)   ])

print('Strain:',strain1[-1])
print('Stress:',max(stress1))
# Out:
# Strain: 0.6076009684087157
# Stress: 4.340885151408713

# %%
# if np.nan in xarr:
#     print("Ya")

# print(math.isnan(df['x'][0]))
# print(np.isin(xarr[0], xarr).any())
# print(xarr)
# print(type(xarr[0]))

# %%
# test = df['x'][0]
# np.isnan(test)

# %%
# mainlist = []
# for i in range(1,6):
#     a = 'v_s15__'
#     b = str(i)
#     c = a+b
#     print(c)
#     c = []
#     for j in range (10):
#         c.append(j)
#     mainlist.append((c))
    
# print(mainlist)
# print(mainlist[0])

# %%
# v_s15_1 = []
# v_s15_2 = []
# v_s15_3 = []
# v_s15_4 = []
# v_s15_5 = []
# #length1 = []
# #length2 = []
# #length3 = []
# #length4 = []
# #length5 = []
# count = 1

# for filename in final_files1:
#     #df1 = pd.read_csv(filename, skiprows = 6, nrows = 1, header = None, engine='python')
#     #print(df1)
#     #st1 = [(float)(df1[0][0].split(' ')[0]), (float)(df1[0][0].split(' ')[1])]
#     #length1.append(st1[1] - st1[0])
#     df11 = pd.read_csv(filename, skiprows=8, sep=" ", engine='python')
#     #print(df)
#     df11 = df11.dropna(axis=1)
#     try:
#         df11.columns = ['ATOMS id', 'type', 'x', 'y', 'z', 'v_s4', 'v_s5', 'v_s6','v_s14', 'v_s15', 'v_s16']
#     except:
#         print('Error.')
#         print("There is nan in " + str(filename))
#         break
#     s_df11 = df11.astype(str)
#     if sum(df11['v_s15'])<-0.001 and count > 10:
#         print("Negative stress, end of calculation 1.")
#         break
#     #elif s_df11["v_s15"].str.contains("nan").any() or s_df11["v_s15"].str.contains("-nan").any():
#     elif any("nan" in s15 for s15 in s_df11['v_s15']):
#         print("Nan exists in file " + str(filename))
#         break
#     else:
#         ans1 = sum(df11['v_s15'])
#         print(ans1)
#         v_s15_1.append(ans1)
#     count += 1
        
# print("First Done!")
# count = 1

# for filename in final_files2:
#     #df2 = pd.read_csv(filename, skiprows = 6, nrows = 1, header = None, engine='python')
#     #print(df2)
#     #st2 = [(float)(df2[0][0].split(' ')[0]), (float)(df2[0][0].split(' ')[1])]
#     #length2.append(st2[1] - st2[0])
#     df22 = pd.read_csv(filename, skiprows=8, sep=" ", engine='python')
#     #print(df)
#     df22 = df22.dropna(axis=1)
#     try:
#         df22.columns = ['ATOMS id', 'type', 'x', 'y', 'z', 'v_s4', 'v_s5', 'v_s6','v_s14', 'v_s15', 'v_s16']
#     except:
#         print('Error.')
#         print("There is nan in " + str(filename))
#         break
#     s_df22 = df22.astype(str)
#     if sum(df22['v_s15'])<-0.001 and count > 10:
#         print("Negative stress, end of calculation 2.")
#         break
#     #elif s_df22["v_s15"].str.contains("nan").any() or s_df22["v_s15"].str.contains("-nan").any():
#     elif any("nan" in s15 for s15 in s_df22['v_s15']):
#         print("Nan exists in file " + str(filename))
#         break
#     else:
#         ans2 = sum(df22['v_s15'])
#         print(ans2)
#         v_s15_2.append(ans2)
#     count += 1
        
# print("Second Done!")
# count = 1

# for filename in final_files3:
#     #df3 = pd.read_csv(filename, skiprows = 6, nrows = 1, header = None, engine='python')
#     #print(df3)
#     #st3 = [(float)(df3[0][0].split(' ')[0]), (float)(df3[0][0].split(' ')[1])]
#     #length3.append(st3[1] - st3[0])
#     df33 = pd.read_csv(filename, skiprows=8, sep=" ", engine='python')
#     #print(df)
#     df33 = df33.dropna(axis=1)
#     try:
#         df33.columns = ['ATOMS id', 'type', 'x', 'y', 'z', 'v_s4', 'v_s5', 'v_s6','v_s14', 'v_s15', 'v_s16']
#     except:
#         print('Error.')
#         print("There is nan in " + str(filename))
#         break
#     s_df33 = df33.astype(str)
#     if sum(df33['v_s15'])<-0.001 and count > 10:
#         print("Negative stress, end of calculation 3.")
#         break
#     #elif s_df33["v_s15"].str.contains("nan").any() or s_df33["v_s15"].str.contains("-nan").any():
#     elif any("nan" in s15 for s15 in s_df33['v_s15']):
#         print("Nan exists in file " + str(filename))
#         break
#     else:
#         ans3 = sum(df33['v_s15'])
#         print(ans3)
#         v_s15_3.append(ans3)
#     count += 1
        
# print("Third Done!")
# count = 1

# for filename in final_files4:
#     #df4 = pd.read_csv(filename, skiprows = 6, nrows = 1, header = None, engine='python')
#     #print(df4)
#     #st4 = [(float)(df4[0][0].split(' ')[0]), (float)(df4[0][0].split(' ')[1])]
#     #length4.append(st4[1] - st4[0])
#     df44 = pd.read_csv(filename, skiprows=8, sep=" ", engine='python')
#     #print(df)
#     df44 = df44.dropna(axis=1)
#     try:
#         df44.columns = ['ATOMS id', 'type', 'x', 'y', 'z', 'v_s4', 'v_s5', 'v_s6','v_s14', 'v_s15', 'v_s16']
#     except:
#         print('Error.')
#         print("There is nan in " + str(filename))
#         break
#     s_df44 = df44.astype(str)
#     if sum(df44['v_s15'])<-0.001 and count > 10:
#         print("Negative stress, end of calculation 4.")
#         break
#     #elif s_df44["v_s15"].str.contains("nan").any() or s_df4["v_s15"].str.contains("-nan").any():
#     elif any("nan" in s15 for s15 in s_df44['v_s15']):
#         print("Nan exists in file " + str(filename))
#         break
#     else:
#         ans4 = sum(df44['v_s15'])
#         print(ans4)
#         v_s15_4.append(ans4)
#     count += 1
    
# print("Fourth Done!")
# count = 1

# for filename in final_files5:
#     #df5 = pd.read_csv(filename, skiprows = 6, nrows = 1, header = None, engine='python')
#     #print(df2)
#     #st5 = [(float)(df5[0][0].split(' ')[0]), (float)(df5[0][0].split(' ')[1])]
#     #length5.append(st5[1] - st5[0])
#     df55 = pd.read_csv(filename, skiprows=8, sep=" ", engine='python')
#     #print(df)
#     df55 = df55.dropna(axis=1)
#     try:
#         df55.columns = ['ATOMS id', 'type', 'x', 'y', 'z', 'v_s4', 'v_s5', 'v_s6','v_s14', 'v_s15', 'v_s16']
#     except:
#         print('Error.')
#         print("There is nan in " + str(filename))
#         break
#     s_df55 = df55.astype(str)
#     if any("nan" in s15 for s15 in s_df55['v_s15']):
#         print("Nan exists in file " + str(filename))
#         break
#     elif sum(df55['v_s15'])<-0.001 and count > 10:
#         print("Negative stress, end of calculation 5.")
#         break
#     #elif s_df55["v_s15"].str.contains("nan").any() or s_df55["v_s15"].str.contains("-nan").any():
#     else:
#         ans5 = sum(df55['v_s15'])
#         print(ans5)
#         v_s15_5.append(ans5)
#     count += 1
        
# print("Fifth Done!")

# %%
# xSize1 = []
# ySize1 = []
# zSize1 = []

# xSize2 = []
# ySize2 = []
# zSize2 = []

# xSize3 = []
# ySize3 = []
# zSize3 = []

# xSize4 = []
# ySize4 = []
# zSize4 = []

# xSize5 = []
# ySize5 = []
# zSize5 = []

# # strain1 = []
# # strain2 = []
# # strain3 = []
# # strain4 = []
# # strain5 = []

# count = 1

# ###  1
# for filename in final_files1:
#     df11 = pd.read_csv(filename, skiprows=8, sep=" ", engine='python')
#     #print(df11)
#     df11 = df11.dropna(axis=1)
#     #print(df11.head())
#     try:
#         df11.columns = ['ATOMS id', 'type', 'x', 'y', 'z', 'v_s4', 'v_s5', 'v_s6','v_s14', 'v_s15', 'v_s16']
#     except:
#         print('Error.')
#         print("There is nan in " + str(filename))
#         break
#     #s_df11 = df11.astype(str)
#     #if pd.isnull(df11['v_s15']).any():
#     #any("nan" in s15 for s15 in s_df11['v_s15']):
#     arr1 = df11['x'].values
#     if math.isnan(df11['x'][0]):
#     #if np.isin(arr1, np.nan).any():
#         print("There is nan in " + str(filename))
#         break        
#     elif sum(df11['v_s15'])<-0.001 and count > 10:
#         print("Negative stress in run 1")
#         break
#     else:
# #         xMin = min(df11['x'])
# #         xMax = max(df11['x'])
# #         yMin = min(df11['y'])
# #         yMax = max(df11['y'])
# #         zMin = min(df11['z'])
# #         zMax = max(df11['z'])
#         xLen = max(df11['x']) - min(df11['x'])
#         yLen = max(df11['y']) - min(df11['y'])
#         zLen = max(df11['z']) - min(df11['z'])
#         xSize1.append(xLen)
#         ySize1.append(yLen)
#         zSize1.append(zLen)
#         print("Length of Y axis is " + str(yLen))
#     #print("Length of x is %.3f" %xLen)
#     #print("Length of y is %.3f" %yLen)
#     #print("Length of z is %.3f" %zLen)
#     count += 1
# print("Run 1 finished!")
# count = 1    
    
# ###  2    
# for filename in final_files2:
#     df22 = pd.read_csv(filename, skiprows=8, sep=" ", engine='python')
#     #print(df)
#     df22 = df22.dropna(axis=1)
#     #print(df)
#     try:
#         df22.columns = ['ATOMS id', 'type', 'x', 'y', 'z', 'v_s4', 'v_s5', 'v_s6','v_s14', 'v_s15', 'v_s16']
#     except:
#         print('Error.')
#         print("There is nan in " + str(filename))
#         break
        
#     #s_df22 = df22.astype(str)
#     arr2 = df22['x'].values
#     #if np.isin(arr2, np.nan).any():
    
#     if math.isnan(df22['x'][0]):
#         print("There is nan in " + str(filename))
#         break
#     elif np.sum(df22['v_s15'].values)<-0.001 and count > 10:
#         print("Negative stress in run 2")
#         break
#     else:
#         xLen = np.max(df22['x'].values) - np.min(df22['x'].values)
#         yLen = np.max(df22['y'].values) - np.min(df22['y'].values)
#         zLen = np.max(df22['z'].values) - np.min(df22['z'].values)
#         xSize2.append(xLen)
#         ySize2.append(yLen)
#         zSize2.append(zLen)
#         print("Length of Y axis is " + str(yLen))
# print("Run 2 finished!")
# count = 1

# ###  3  
# for filename in final_files3:
#     df33 = pd.read_csv(filename, skiprows=8, sep=" ", engine='python')
#     #print(df)
#     df33 = df33.dropna(axis=1)
#     try:
#         df33.columns = ['ATOMS id', 'type', 'x', 'y', 'z', 'v_s4', 'v_s5', 'v_s6','v_s14', 'v_s15', 'v_s16']
#     except:
#         print('Error.')
#         print("There is nan in " + str(filename))
#         break
#     arr3 = df33['x'].values
#     #if np.isin(arr3, np.nan).any():
#     if math.isnan(df33['x'][0]):
#         print("There is nan in " + str(filename))
#         break
#     elif sum(df33['v_s15'])<-0.001 and count > 10:
#         print("Negative stress in run 3")
#         break
#     else:
#         xLen = max(df33['x']) - min(df33['x'])
#         yLen = max(df33['y']) - min(df33['y'])
#         zLen = max(df33['z']) - min(df33['z'])
#         xSize3.append(xLen)
#         ySize3.append(yLen)
#         zSize3.append(zLen)
#         print("Length of Y axis is " + str(yLen))
# print("Run 3 finished!")
# count = 1

# ###  4
# for filename in final_files2:
#     df44 = pd.read_csv(filename, skiprows=8, sep=" ", engine='python')
#     #print(df)
#     df44 = df44.dropna(axis=1)
#     try:
#         df44.columns = ['ATOMS id', 'type', 'x', 'y', 'z', 'v_s4', 'v_s5', 'v_s6','v_s14', 'v_s15', 'v_s16']
#     except:
#         print('Error.')
#         print("There is nan in " + str(filename))
#         break
#     arr4 = df44['x'].values
#     #if np.isin(arr4, np.nan).any():
#     if math.isnan(df44['x'][0]):
#         print("There is nan in " + str(filename))
#         break
#     elif sum(df44['v_s15'])<-0.001 and count > 10:
#         print("Negative stress in run 4")
#         break
#     else:
#         xLen = max(df44['x']) - min(df44['x'])
#         yLen = max(df44['y']) - min(df44['y'])
#         zLen = max(df44['z']) - min(df44['z'])
#         xSize4.append(xLen)
#         ySize4.append(yLen)
#         zSize4.append(zLen)
#         print("Length of Y axis is " + str(yLen))
# print("Run 4 finished!")
# count = 1

# ###  5
# for filename in final_files5:
#     df55 = pd.read_csv(filename, skiprows=8, sep=" ", engine='python')
#     #print(df)
#     df55 = df55.dropna(axis=1)
#     try:
#         df55.columns = ['ATOMS id', 'type', 'x', 'y', 'z', 'v_s4', 'v_s5', 'v_s6','v_s14', 'v_s15', 'v_s16']
#     except:
#         print('Error.')
#         print("There is nan in " + str(filename))
#         break
#     arr5 = df55['x'].values
#     #if np.isin(arr5, np.nan).any():
#     if math.isnan(df55['x'][0]):
#         print("There is nan in " + str(filename))
#         break
#     elif sum(df55['v_s15'])<-0.001 and count > 10:
#         print("Negative stress in run 5")
#         break
#     else:
#         xLen = max(df55['x']) - min(df55['x'])
#         yLen = max(df55['y']) - min(df55['y'])
#         zLen = max(df55['z']) - min(df55['z'])
#         xSize5.append(xLen)
#         ySize5.append(yLen)
#         zSize5.append(zLen)
#         print("Length of Y axis is " + str(yLen))
# print("Run 5 finished!")
